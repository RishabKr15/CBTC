# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabKr15/CBTC/blob/main/Data_Manipulation_with_Pandas_%5BComplete%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Topics
# 1. Series and dataframes
# 2. Setting up the directory : (OS Package)
# 3. Loading different file formats
# 4. Basic Inspection of dataset
# 5. Indexing & Slicing
# 6. Creating new columns, renaming & droping
# 6. Handling Missing Values
# 7. Sorting & Handling Duplicates
# 8. Aggregating Data
# 9. Joining Datasets
# 10. .replace(),.apply()
# 11. Dealing with Strings, Datetime & Json data in column
# 12. Reshaping data
# 13. Caching & Parallelization
# 14. Writing data

# %%
#Import package
import pandas as pd

# %% [markdown]
# ### Series and Dataframe

# %%
# Series: A series is essentially a column (1-D data)
# Data Frame: A DataFrame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
# Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %%
# Series
s1 = pd.Series([28, 20, 32, 40])
s2 = pd.Series(['John','David','Reva','Grahm'])
print(s1)
print(type(s1))
# Out:
# 0    28
# 1    20
# 2    32
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Dataframe
df = pd.DataFrame({'age':s1,'name':s2})
print(df)
print(type(df))
# Out:
#    age   name
# 0   28   John
# 1   20  David
# 2   32   Reva
# 3   40  Grahm
# <class 'pandas.core.frame.DataFrame'>

# %%
# Different Ways of creating a dataframe
# List of list
list_of_lists = [['John', 20,'NY'], ['David', 20, 'CL'], ['Reva', 32],['Grahm',40,'NZ']]
df = pd.DataFrame(list_of_lists, columns = ['name','age','city'])
print(df)
# Out:
#     name  age  city
# 0   John   20    NY
# 1  David   20    CL
# 2   Reva   32  None
# 3  Grahm   40    NZ

# %%
# Use Dictionaries --> Most Common way to create dataframe
name_dict = {'name':['John','David','Reva','Grahm'], 'age':[28, 20, 32, 40]}
# Name of column as key and value as records for that specific column
# Create DataFrame
df = pd.DataFrame(name_dict)
print(df)
# Out:
#     name  age
# 0   John   28
# 1  David   20
# 2   Reva   32
# 3  Grahm   40

# %%
# list of dictionaries
list_dict = [{'name':'John','age':28,'city':'NY'},{'name':'David','age':20,'city':'CA'},{'name':'Reva','age':32,'city':'AUS'},{'name':'Grahm','age':40,'city':'NZ'}]

# Create DataFrame
df = pd.DataFrame(list_dict)
print(df)
# Out:
#     name  age city
# 0   John   28   NY
# 1  David   20   CA
# 2   Reva   32  AUS
# 3  Grahm   40   NZ

# %% [markdown]
# ### Setting up the directory

# %%
# Project data files - https://drive.google.com/drive/folders/1vLMCY81mZ2l_zNRsiK2Trs1DtumITSla?usp=sharing

# %%
import os
os.getcwd() # Get the current directory
# Out:
# '/content/sample_data'

# %%
# !ls # Command to see the folder available
# Out:
# anscombe.json		     california_housing_train.csv  mnist_test.csv	  README.md
# california_housing_test.csv  dataframe.xlsx		   mnist_train_small.csv

# %%
# Setting up directory helps access the files easily.
os.chdir('/content/sample_data')
os.getcwd()
# Out:
# '/content/sample_data'

# %%
# Example of loading the file
# df = pd.read_csv('mnist_test.csv')

# %%
# df.head(1)

# %%
# Note: Google colab can't access the files or folder present in the google drive unless it it mounted

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
# Out:
# '/content/sample_data'

# %%
# Change the working directory to project folder
os.chdir('/content/drive/MyDrive/M2_Project')
os.getcwd()
# Out:
# '/content/drive/MyDrive/M2_Project'

# %%
# !ls # List the files
# Out:
# bash.xml  employee.json  Products.xlsx	       read_imdb_data_w.xlsx
# cache	  imdb_data.csv  read_imdb_data_w.csv  Superstore.xlsx

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/M2_Project'

# %%
# os.chdir()

# %%
# pd.read_csv('/content/drive/MyDrive/A0Z5AGRAGTQK (1).csv')

# %% [markdown]
# ### Loading different file formats

# %% [markdown]
# #### Different types of file
# 1. CSV
# 2. Excel
# 3. JSON (JavaScript Object Notation)
# 4. XML (Extensible Markup Language)

# %%
# !ls
# Out:
# sample_data

# %%
# Reading CSV file
read_imdb_data = pd.read_csv('imdb_data.csv')
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
# !ls

# %%
# Read Excel file
# Default first sheet
df = pd.read_excel("Products.xlsx")
print(df)

# Mention Sheet name
df = pd.read_excel("Products.xlsx",sheet_name = 'grocery')
print(df)

# %%
# JSON (JavaScript Object Notation)
df = pd.read_json('employee.json')
df

# %%
# Reading XML File
df = pd.read_xml('bash.xml')
df

# %% [markdown]
# ### Basic Inspection of dataset

# %%
# shape,head(n),tail(n),columns,describe(),info()

# %%
read_imdb_data.shape
# Out:
# (3000, 23)

# %%
read_imdb_data.head(1) # First n rows : default 5
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.tail(1) # last n rows : default 5
# Out:
#         id belongs_to_collection    budget  \
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#      original_title                                           overview  \
# 2999      Abduction  A young man sets out to uncover the truth abou...
#
#       popularity  ... release_date runtime  \
# 2999   10.512109  ...      9/22/11   106.0
#
#                               spoken_languages    status  \
# 2999  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                         tagline      title  \
# 2999  They stole his life. He's taking it back.  Abduction
#
#                                                Keywords  \
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew   revenue
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155
#
# [1 rows x 23 columns]

# %%
read_imdb_data.columns # name of columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
read_imdb_data.describe() # Inspection of continous data
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
read_imdb_data.describe(include= 'all') # Analysis of continous & Categorical data
# Out:
#                  id                              belongs_to_collection  \
# count   3000.000000                                                604
# unique          NaN                                                422
# top             NaN  [{'id': 645, 'name': 'James Bond Collection', ...
# freq            NaN                                                 16
# mean    1500.500000                                                NaN
# std      866.169729                                                NaN
# min        1.000000                                                NaN
# 25%      750.750000                                                NaN
# 50%     1500.500000                                                NaN
# 75%     2250.250000                                                NaN
# max     3000.000000                                                NaN
#
#               budget                         genres  \
# count   3.000000e+03                           2993
# unique           NaN                            872
# top              NaN  [{'id': 18, 'name': 'Drama'}]
# freq             NaN                            266
# mean    2.253133e+07                            NaN
# std     3.702609e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     0.000000e+00                            NaN
# 50%     8.000000e+06                            NaN
# 75%     2.900000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage    imdb_id original_language  \
# count                                 946       3000              3000
# unique                                941       3000                36
# top     http://www.transformersmovie.com/  tt2637294                en
# freq                                    4          1              2575
# mean                                  NaN        NaN               NaN
# std                                   NaN        NaN               NaN
# min                                   NaN        NaN               NaN
# 25%                                   NaN        NaN               NaN
# 50%                                   NaN        NaN               NaN
# 75%                                   NaN        NaN               NaN
# max                                   NaN        NaN               NaN
#
#        original_title                                           overview  \
# count            3000                                               2992
# unique           2975                                               2992
# top            Joshua  When Lou, who has become the "father of the In...
# freq                2                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#          popularity  ... release_date      runtime  \
# count   3000.000000  ...         3000  2998.000000
# unique          NaN  ...         2398          NaN
# top             NaN  ...      9/10/10          NaN
# freq            NaN  ...            5          NaN
# mean       8.463274  ...          NaN   107.856571
# std       12.104000  ...          NaN    22.086434
# min        0.000001  ...          NaN     0.000000
# 25%        4.018053  ...          NaN    94.000000
# 50%        7.374861  ...          NaN   104.000000
# 75%       10.890983  ...          NaN   118.000000
# max      294.337037  ...          NaN   338.000000
#
#                                 spoken_languages    status  \
# count                                       2980      3000
# unique                                       401         2
# top     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# freq                                        1817      2996
# mean                                         NaN       NaN
# std                                          NaN       NaN
# min                                          NaN       NaN
# 25%                                          NaN       NaN
# 50%                                          NaN       NaN
# 75%                                          NaN       NaN
# max                                          NaN       NaN
#
#                        tagline                  title  \
# count                     2403                   3000
# unique                    2400                   2969
# top     Based on a true story.  The Magnificent Seven
# freq                         3                      2
# mean                       NaN                    NaN
# std                        NaN                    NaN
# min                        NaN                    NaN
# 25%                        NaN                    NaN
# 50%                        NaN                    NaN
# 75%                        NaN                    NaN
# max                        NaN                    NaN
#
#                                            Keywords  cast  \
# count                                          2724  2987
# unique                                         2648  2975
# top     [{'id': 10183, 'name': 'independent film'}]    []
# freq                                             27    13
# mean                                            NaN   NaN
# std                                             NaN   NaN
# min                                             NaN   NaN
# 25%                                             NaN   NaN
# 50%                                             NaN   NaN
# 75%                                             NaN   NaN
# max                                             NaN   NaN
#
#                                                      crew       revenue
# count                                                2984  3.000000e+03
# unique                                               2984           NaN
# top     [{'credit_id': '59ac067c92514107af02c8c8', 'de...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  6.672585e+07
# std                                                   NaN  1.375323e+08
# min                                                   NaN  1.000000e+00
# 25%                                                   NaN  2.379808e+06
# 50%                                                   NaN  1.680707e+07
# 75%                                                   NaN  6.891920e+07
# max                                                   NaN  1.519558e+09
#
# [11 rows x 23 columns]

# %%
read_imdb_data.info() # Information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
# Inspection of select few columns
read_imdb_data[['id', 'original_title','runtime','revenue', 'budget', 'genres','imdb_id', 'original_language' ]]
# Out:
#         id                            original_title  runtime    revenue  \
# 0        1                    Hot Tub Time Machine 2     93.0   12314651
# 1        2  The Princess Diaries 2: Royal Engagement    113.0   95149435
# 2        3                                  Whiplash    105.0   13092000
# 3        4                                   Kahaani    122.0   16000000
# 4        5                                      마린보이    118.0    3923970
# ...    ...                                       ...      ...        ...
# 2995  2996                                   Chasers    102.0    1596687
# 2996  2997                               Vi är bäst!    102.0     180590
# 2997  2998                   The Long Kiss Goodnight    120.0   89456761
# 2998  2999                          Along Came Polly     90.0  171963386
# 2999  3000                                 Abduction    106.0   82087155
#
#         budget                                             genres    imdb_id  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# ...        ...                                                ...        ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0109403
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...  tt2364975
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...  tt0116908
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0343135
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...  tt1600195
#
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   hi
# 4                   ko
# ...                ...
# 2995                en
# 2996                sv
# 2997                en
# 2998                en
# 2999                en
#
# [3000 rows x 8 columns]

# %%
# Important Points to remember :

# %% [markdown]
# ### Indexing and Slicing()

# %%
# loc(), iloc(), Boolean indexing

# %%
# Understanding the index
# list of dictionaries
list_dict = [{'name':'John','age':28},{'name':'David','age':20},{'name':'Reva','age':32},{'name':'Grahm','age':40}]

# Create DataFrame
df = pd.DataFrame(list_dict,index = ['A','B','C','D'])
df
# Out:
#     name  age
# A   John   28
# B  David   20
# C   Reva   32
# D  Grahm   40

# %%
df.loc[['A','C'],['name','age']] # 1st part row subset, 2nd part column
# Out:
#    name  age
# A  John   28
# C  Reva   32

# %%
df.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
df
# Out:
#     name  age
# A   John   28
# B  David   20
# C   Reva   32
# D  Grahm   40

# %%
df
# Out:
#     name  age
# A   John   28
# B  David   20
# C   Reva   32
# D  Grahm   40

# %%
df.iloc[[1,3],[0]] # Column until 2nd index
# Out:
#     name
# B  David
# D  Grahm

# %%
# loc(): When Subsetting is done by index and column names
# iloc(): When Subsetting is done by index and column number

# df.loc[10:40, ['name']]
# df.iloc[:4,:1]

# %%
# .loc[] --> Column names defined and you want to deal few column
# .iloc[] -->

# %%
# loc(): When Subsetting is done by index and column name
read_imdb_data.loc[50:55,['budget','genres','runtime']] # rows and columns
# Out:
#       budget                                             genres  runtime
# 50    560000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...    102.0
# 51  12000000  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...    160.0
# 52         0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...     97.0
# 53         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...     98.0
# 54  20000000                     [{'id': 28, 'name': 'Action'}]    107.0
# 55         0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     95.0

# %%
read_imdb_data.loc[:5,]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
# 5                                NaN  tt0093743                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
# 5  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
#
# [6 rows x 23 columns]

# %%
read_imdb_data.loc[3:5,] # till 5 all columns, 3 & 5 is included
# Out:
#    id belongs_to_collection   budget  \
# 3   4                   NaN  1200000
# 4   5                   NaN        0
# 5   6                   NaN  8000000
#
#                                               genres  \
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
#
#                      homepage    imdb_id original_language  \
# 3  http://kahaanithefilm.com/  tt1821480                hi
# 4                         NaN  tt1380152                ko
# 5                         NaN  tt0093743                en
#
#                            original_title  \
# 3                                 Kahaani
# 4                                    마린보이
# 5  Pinocchio and the Emperor of the Night
#
#                                             overview  popularity  ...  \
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
#
#   release_date runtime                                   spoken_languages  \
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline                                   title  \
# 3  Released      NaN                                 Kahaani
# 4  Released      NaN                              Marine Boy
# 5  Released      NaN  Pinocchio and the Emperor of the Night
#
#                                             Keywords  \
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
#
#                                                 cast  \
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
#
#                                                 crew   revenue
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
#
# [3 rows x 23 columns]

# %%
df
# Out:
#     name  age
# A   John   28
# B  David   20
# C   Reva   32
# D  Grahm   40

# %%
df.index[-3:-1]
# Out:
# Index(['B', 'C'], dtype='object')

# %%
df.loc[df.index[-3:-1],['name']]
# Out:
#     name
# B  David
# C   Reva

# %%
read_imdb_data.index[-5:]
# Out:
# RangeIndex(start=2995, stop=3000, step=1)

# %%
read_imdb_data.loc[read_imdb_data.index[-5:] , ] # last 5 data using loc :; Use .index to use the negative index
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996      3/28/13   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [5 rows x 23 columns]

# %%
# -50 to -40 rows using loc for read_imdb_data
# read_imdb_data.loc[read_imdb_data.index[-50:-40] , 'genres' ]

# %%
read_imdb_data.loc[[34,56,78] , :] # Only specific rows
# Out:
#     id                              belongs_to_collection     budget  \
# 34  35  [{'id': 90863, 'name': 'Rush Hour Collection',...  140000000
# 56  57                                                NaN          0
# 78  79                                                NaN          0
#
#                                                genres  \
# 34  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 56  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 78  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#
#                           homepage    imdb_id original_language  \
# 34                             NaN  tt0293564                en
# 56  http://www.joueuse-lefilm.com/  tt1082009                fr
# 78                             NaN  tt0083064                en
#
#       original_title                                           overview  \
# 34       Rush Hour 3  After an attempted assassination on Ambassador...
# 56           Joueuse  In a small Corsican village, the life of Hélèn...
# 78  Sharky's Machine  Sharky gets busted back to working vice, where...
#
#     popularity  ... release_date runtime  \
# 34    9.718111  ...       8/8/07    91.0
# 56    2.947980  ...       8/5/09    97.0
# 78    2.633399  ...     12/18/81   122.0
#
#                                      spoken_languages    status  \
# 34  [{'iso_639_1': 'la', 'name': 'Latin'}, {'iso_6...  Released
# 56  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 78           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline             title  \
# 34                                    The Rush Is On!       Rush Hour 3
# 56                                                NaN     Queen to Play
# 78  If you mess with a cop like Sharky, you better...  Sharky's Machine
#
#                                              Keywords  \
# 34               [{'id': 1704, 'name': 'ambassador'}]
# 56  [{'id': 316, 'name': 'chess'}, {'id': 3797, 'n...
# 78  [{'id': 108, 'name': 'transvestism'}, {'id': 6...
#
#                                                  cast  \
# 34  [{'cast_id': 2, 'character': 'Det. James Carte...
# 56  [{'cast_id': 1, 'character': 'H√©l√®ne', 'cred...
# 78  [{'cast_id': 3, 'character': 'Tom Sharky', 'cr...
#
#                                                  crew    revenue
# 34  [{'credit_id': '52fe43fac3a36847f807b5bd', 'de...  258022233
# 56  [{'credit_id': '52fe4624c3a36847f80eefcf', 'de...    1056938
# 78  [{'credit_id': '555507869251411e620004c9', 'de...   35610100
#
# [3 rows x 23 columns]

# %%
read_imdb_data.loc[read_imdb_data.index[[-3,-1,-2]] , :] # Only specific rows if negative index is used.
# Out:
#         id belongs_to_collection    budget  \
# 2997  2998                   NaN  65000000
# 2999  3000                   NaN  35000000
# 2998  2999                   NaN  42000000
#
#                                                  genres  \
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                               homepage    imdb_id original_language  \
# 2997                               NaN  tt0116908                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
#
#                original_title  \
# 2997  The Long Kiss Goodnight
# 2999                Abduction
# 2998         Along Came Polly
#
#                                                overview  popularity  ...  \
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
#
#      release_date runtime                          spoken_languages    status  \
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2997               What's forgotten is not always gone.
# 2999          They stole his life. He's taking it back.
# 2998  For the most cautious man on Earth, life is ab...
#
#                         title  \
# 2997  The Long Kiss Goodnight
# 2999                Abduction
# 2998         Along Came Polly
#
#                                                Keywords  \
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
#
#                                                    cast  \
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
#
#                                                    crew    revenue
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
#
# [3 rows x 23 columns]

# %%
read_imdb_data.loc[:10,]
# Out:
#     id                              belongs_to_collection    budget  \
# 0    1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1    2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2    3                                                NaN   3300000
# 3    4                                                NaN   1200000
# 4    5                                                NaN         0
# 5    6                                                NaN   8000000
# 6    7                                                NaN  14000000
# 7    8                                                NaN         0
# 8    9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9   10                                                NaN   6000000
# 10  11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                 [{'id': 99, 'name': 'Documentary'}]
# 8   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9   [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                               homepage    imdb_id original_language  \
# 0                                  NaN  tt2637294                en
# 1                                  NaN  tt0368933                en
# 2    http://sonyclassics.com/whiplash/  tt2582802                en
# 3           http://kahaanithefilm.com/  tt1821480                hi
# 4                                  NaN  tt1380152                ko
# 5                                  NaN  tt0093743                en
# 6   http://www.thepossessionmovie.com/  tt0431021                en
# 7                                  NaN  tt0391024                en
# 8                                  NaN  tt0117110                en
# 9                                  NaN  tt0310281                en
# 10                                 NaN  tt0075148                en
#
#                               original_title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                       마린보이
# 5     Pinocchio and the Emperor of the Night
# 6                             The Possession
# 7                               Control Room
# 8                     Muppet Treasure Island
# 9                              A Mighty Wind
# 10                                     Rocky
#
#                                              overview  popularity  ...  \
# 0   When Lou, who has become the "father of the In...    6.575393  ...
# 1   Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2   Under the direction of a ruthless instructor, ...   64.299990  ...
# 3   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4   Marine Boy is the story of a former national s...    1.148070  ...
# 5   Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6   A young girl buys an antique box at a yard sal...    7.286477  ...
# 7   A chronicle which provides a rare window into ...    1.949044  ...
# 8   After telling the story of Flint's last journe...    6.902423  ...
# 9   In "A Mighty Wind", director Christopher Guest...    4.672036  ...
# 10  When world heavyweight boxing champion, Apollo...   14.774066  ...
#
#    release_date runtime                                   spoken_languages  \
# 0       2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1        8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2      10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4        2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5        8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6       8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7       1/15/04    84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8       2/16/96   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9       4/16/03    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10     11/21/76   119.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 0   Released  The Laws of Space and Time are About to be Vio...
# 1   Released  It can take a lifetime to find true love; she'...
# 2   Released    The road to greatness can take you to the edge.
# 3   Released                                                NaN
# 4   Released                                                NaN
# 5   Released                                                NaN
# 6   Released               Fear The Demon That Doesn't Fear God
# 7   Released              Different channels. Different truths.
# 8   Released                        Set sail for Muppet mayhem!
# 9   Released           Back together for the first time, again.
# 10  Released          His whole life was a million-to-one shot.
#
#                                        title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                 Marine Boy
# 5     Pinocchio and the Emperor of the Night
# 6                             The Possession
# 7                               Control Room
# 8                     Muppet Treasure Island
# 9                              A Mighty Wind
# 10                                     Rocky
#
#                                              Keywords  \
# 0   [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8   [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 9   [{'id': 11800, 'name': 'mockumentary'}, {'id':...
# 10  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
#
#                                                  cast  \
# 0   [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5   [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6   [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7   [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8   [{'cast_id': 1, 'character': 'Long John Silver...
# 9   [{'cast_id': 24, 'character': 'Jonathan Steinb...
# 10  [{'cast_id': 16, 'character': 'Rocky Balboa', ...
#
#                                                  crew    revenue
# 0   [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1   [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 5   [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# 6   [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075
# 7   [{'credit_id': '52fe47a69251416c750a0daf', 'de...    2586511
# 8   [{'credit_id': '52fe43c89251416c7501deb3', 'de...   34327391
# 9   [{'credit_id': '52fe45609251416c750545b3', 'de...   18750246
# 10  [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
#
# [11 rows x 23 columns]

# %%
# iloc : When Subsetting is done by row and column number
read_imdb_data.iloc[ : 10,  : 4] # index 10 & 4 is excluded
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...

# %%
read_imdb_data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
read_imdb_data.iloc[ 3: 5,  1: 4] # index 5 & 4 is excluded
# Out:
#   belongs_to_collection   budget  \
# 3                   NaN  1200000
# 4                   NaN        0
#
#                                               genres
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...

# %%
read_imdb_data.loc[ read_imdb_data.index[-50:-40],  ]
# Out:
#         id                              belongs_to_collection    budget  \
# 2950  2951  [{'id': 9735, 'name': 'Friday the 13th Collect...  30000000
# 2951  2952                                                NaN  13000000
# 2952  2953                                                NaN  25000000
# 2953  2954                                                NaN   8500000
# 2954  2955                                                NaN  60000000
# 2955  2956                                                NaN  17000000
# 2956  2957                                                NaN         0
# 2957  2958                                                NaN  60000000
# 2958  2959                                                NaN  15000000
# 2959  2960                                                NaN   2300000
#
#                                                  genres  \
# 2950                     [{'id': 27, 'name': 'Horror'}]
# 2951  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2952  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 2953  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2954                     [{'id': 35, 'name': 'Comedy'}]
# 2955  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2956  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2957  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2958  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                              homepage    imdb_id original_language  \
# 2950                              NaN  tt0329101                en
# 2951                              NaN  tt2057392                en
# 2952  http://theageofadalinemovie.com  tt1655441                en
# 2953                              NaN  tt0202677                en
# 2954                              NaN  tt0375173                en
# 2955                              NaN  tt1210042                en
# 2956                              NaN  tt0091055                en
# 2957                              NaN  tt0113845                en
# 2958        http://www.u23dmovie.com/  tt0892375                en
# 2959                              NaN  tt1093370                hi
#
#           original_title                                           overview  \
# 2950    Freddy vs. Jason  Evil dream-demon Freddy Krueger devises a plan...
# 2951      Eye in the Sky  A military officer in command of a drone opera...
# 2952  The Age of Adaline  After 29-year-old Adaline recovers from a near...
# 2953  The Way of the Gun  Parker and Longbaugh are a pair of low-level p...
# 2954               Alfie  In Manhattan, the British limousine driver Alf...
# 2955   Brooklyn's Finest  Enforcing the law within the notoriously rough...
# 2956          Firewalker  A pair of adventurers try to track down an anc...
# 2957         Money Train  A vengeful New York transit cop decides to ste...
# 2958               U2 3D  A 3-D presentation of U2's global "Vertigo" to...
# 2959          Jab We Met  Depressed after the passing of his father, Dha...
#
#       popularity  ... release_date runtime  \
# 2950   14.015739  ...      8/15/03    97.0
# 2951   10.564701  ...      9/11/15   102.0
# 2952   10.542026  ...      4/16/15   112.0
# 2953    6.036330  ...       9/8/00   119.0
# 2954   10.411608  ...     10/22/04   103.0
# 2955   12.504220  ...      1/16/09   133.0
# 2956    3.150899  ...     11/21/86   104.0
# 2957    7.337906  ...     11/21/95   103.0
# 2958    0.900864  ...      5/19/07    85.0
# 2959    3.959411  ...     10/26/07   145.0
#
#                                        spoken_languages    status  \
# 2950           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2951  [{'iso_639_1': 'so', 'name': 'Somali'}, {'iso_...  Released
# 2952           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2953  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2954           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2955           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2956  [{'iso_639_1': 'hu', 'name': 'Magyar'}, {'iso_...  Released
# 2957           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2958           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2959  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...  Released
#
#                                                 tagline               title  \
# 2950                              Evil Will Battle Evil    Freddy vs. Jason
# 2951                      Welcome to the new front line      Eye in the Sky
# 2952                                  Love is timeless.  The Age of Adaline
# 2953                                                NaN  The Way of the Gun
# 2954   Meet a man who never met a woman he didn't love.               Alfie
# 2955                     This is War. This is Brooklyn.   Brooklyn's Finest
# 2956  A pair of down-and-out fortune hunters cash in...          Firewalker
# 2957                        Get on, or GET OUT THE WAY!         Money Train
# 2958                                Hear See Experience               U2 3D
# 2959                                                NaN          Jab We Met
#
#                                                Keywords  \
# 2950  [{'id': 9826, 'name': 'murder'}, {'id': 10776,...
# 2951  [{'id': 949, 'name': 'terrorist'}, {'id': 1193...
# 2952  [{'id': 582, 'name': 'san francisco'}, {'id': ...
# 2953  [{'id': 75, 'name': 'gunslinger'}, {'id': 534,...
# 2954  [{'id': 242, 'name': 'new york'}, {'id': 1332,...
# 2955  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 2956  [{'id': 352, 'name': 'secret passage'}, {'id':...
# 2957  [{'id': 380, 'name': 'brother brother relation...
# 2958                                                NaN
# 2959  [{'id': 2038, 'name': "love of one's life"}, {...
#
#                                                    cast  \
# 2950  [{'cast_id': 1, 'character': 'Freddy Krueger',...
# 2951  [{'cast_id': 4, 'character': 'Colonel Katherin...
# 2952  [{'cast_id': 0, 'character': 'Adaline Bowman',...
# 2953  [{'cast_id': 1, 'character': 'Mr. Longbaugh', ...
# 2954  [{'cast_id': 1, 'character': 'Alfie', 'credit_...
# 2955  [{'cast_id': 3, 'character': 'Eddie Dugan', 'c...
# 2956  [{'cast_id': 1, 'character': 'Max Donigan', 'c...
# 2957  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 2958  [{'cast_id': 0, 'character': 'Himself', 'credi...
# 2959  [{'cast_id': 9, 'character': 'Aditya Kashyap',...
#
#                                                    crew    revenue
# 2950  [{'credit_id': '52fe4453c3a36847f808f4a5', 'de...  114908830
# 2951  [{'credit_id': '55186708c3a36862f6004623', 'de...   18704595
# 2952  [{'credit_id': '54721093c3a3686792002bc5', 'de...   65663276
# 2953  [{'credit_id': '52fe4305c3a36847f8034691', 'de...   19125401
# 2954  [{'credit_id': '562643e89251413ded006a07', 'de...   13395939
# 2955  [{'credit_id': '52fe4500c3a368484e042e7b', 'de...   29536299
# 2956  [{'credit_id': '52fe45199251416c7504bbf7', 'de...   11949484
# 2957  [{'credit_id': '52fe44509251416c750305a1', 'de...   35431113
# 2958  [{'credit_id': '57bfd2089251414b1500001e', 'de...   22730842
# 2959  [{'credit_id': '537ef0d8c3a36805a1002844', 'de...    4600000
#
# [10 rows x 23 columns]

# %%
read_imdb_data.iloc[ -50:-40,  ] # last three rows and last 2 columns # No need to use .index here.
# Out:
#         id                              belongs_to_collection    budget  \
# 2950  2951  [{'id': 9735, 'name': 'Friday the 13th Collect...  30000000
# 2951  2952                                                NaN  13000000
# 2952  2953                                                NaN  25000000
# 2953  2954                                                NaN   8500000
# 2954  2955                                                NaN  60000000
# 2955  2956                                                NaN  17000000
# 2956  2957                                                NaN         0
# 2957  2958                                                NaN  60000000
# 2958  2959                                                NaN  15000000
# 2959  2960                                                NaN   2300000
#
#                                                  genres  \
# 2950                     [{'id': 27, 'name': 'Horror'}]
# 2951  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2952  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 2953  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2954                     [{'id': 35, 'name': 'Comedy'}]
# 2955  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2956  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2957  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2958  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                              homepage    imdb_id original_language  \
# 2950                              NaN  tt0329101                en
# 2951                              NaN  tt2057392                en
# 2952  http://theageofadalinemovie.com  tt1655441                en
# 2953                              NaN  tt0202677                en
# 2954                              NaN  tt0375173                en
# 2955                              NaN  tt1210042                en
# 2956                              NaN  tt0091055                en
# 2957                              NaN  tt0113845                en
# 2958        http://www.u23dmovie.com/  tt0892375                en
# 2959                              NaN  tt1093370                hi
#
#           original_title                                           overview  \
# 2950    Freddy vs. Jason  Evil dream-demon Freddy Krueger devises a plan...
# 2951      Eye in the Sky  A military officer in command of a drone opera...
# 2952  The Age of Adaline  After 29-year-old Adaline recovers from a near...
# 2953  The Way of the Gun  Parker and Longbaugh are a pair of low-level p...
# 2954               Alfie  In Manhattan, the British limousine driver Alf...
# 2955   Brooklyn's Finest  Enforcing the law within the notoriously rough...
# 2956          Firewalker  A pair of adventurers try to track down an anc...
# 2957         Money Train  A vengeful New York transit cop decides to ste...
# 2958               U2 3D  A 3-D presentation of U2's global "Vertigo" to...
# 2959          Jab We Met  Depressed after the passing of his father, Dha...
#
#       popularity  ... release_date runtime  \
# 2950   14.015739  ...      8/15/03    97.0
# 2951   10.564701  ...      9/11/15   102.0
# 2952   10.542026  ...      4/16/15   112.0
# 2953    6.036330  ...       9/8/00   119.0
# 2954   10.411608  ...     10/22/04   103.0
# 2955   12.504220  ...      1/16/09   133.0
# 2956    3.150899  ...     11/21/86   104.0
# 2957    7.337906  ...     11/21/95   103.0
# 2958    0.900864  ...      5/19/07    85.0
# 2959    3.959411  ...     10/26/07   145.0
#
#                                        spoken_languages    status  \
# 2950           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2951  [{'iso_639_1': 'so', 'name': 'Somali'}, {'iso_...  Released
# 2952           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2953  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2954           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2955           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2956  [{'iso_639_1': 'hu', 'name': 'Magyar'}, {'iso_...  Released
# 2957           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2958           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2959  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...  Released
#
#                                                 tagline               title  \
# 2950                              Evil Will Battle Evil    Freddy vs. Jason
# 2951                      Welcome to the new front line      Eye in the Sky
# 2952                                  Love is timeless.  The Age of Adaline
# 2953                                                NaN  The Way of the Gun
# 2954   Meet a man who never met a woman he didn't love.               Alfie
# 2955                     This is War. This is Brooklyn.   Brooklyn's Finest
# 2956  A pair of down-and-out fortune hunters cash in...          Firewalker
# 2957                        Get on, or GET OUT THE WAY!         Money Train
# 2958                                Hear See Experience               U2 3D
# 2959                                                NaN          Jab We Met
#
#                                                Keywords  \
# 2950  [{'id': 9826, 'name': 'murder'}, {'id': 10776,...
# 2951  [{'id': 949, 'name': 'terrorist'}, {'id': 1193...
# 2952  [{'id': 582, 'name': 'san francisco'}, {'id': ...
# 2953  [{'id': 75, 'name': 'gunslinger'}, {'id': 534,...
# 2954  [{'id': 242, 'name': 'new york'}, {'id': 1332,...
# 2955  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 2956  [{'id': 352, 'name': 'secret passage'}, {'id':...
# 2957  [{'id': 380, 'name': 'brother brother relation...
# 2958                                                NaN
# 2959  [{'id': 2038, 'name': "love of one's life"}, {...
#
#                                                    cast  \
# 2950  [{'cast_id': 1, 'character': 'Freddy Krueger',...
# 2951  [{'cast_id': 4, 'character': 'Colonel Katherin...
# 2952  [{'cast_id': 0, 'character': 'Adaline Bowman',...
# 2953  [{'cast_id': 1, 'character': 'Mr. Longbaugh', ...
# 2954  [{'cast_id': 1, 'character': 'Alfie', 'credit_...
# 2955  [{'cast_id': 3, 'character': 'Eddie Dugan', 'c...
# 2956  [{'cast_id': 1, 'character': 'Max Donigan', 'c...
# 2957  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 2958  [{'cast_id': 0, 'character': 'Himself', 'credi...
# 2959  [{'cast_id': 9, 'character': 'Aditya Kashyap',...
#
#                                                    crew    revenue
# 2950  [{'credit_id': '52fe4453c3a36847f808f4a5', 'de...  114908830
# 2951  [{'credit_id': '55186708c3a36862f6004623', 'de...   18704595
# 2952  [{'credit_id': '54721093c3a3686792002bc5', 'de...   65663276
# 2953  [{'credit_id': '52fe4305c3a36847f8034691', 'de...   19125401
# 2954  [{'credit_id': '562643e89251413ded006a07', 'de...   13395939
# 2955  [{'credit_id': '52fe4500c3a368484e042e7b', 'de...   29536299
# 2956  [{'credit_id': '52fe45199251416c7504bbf7', 'de...   11949484
# 2957  [{'credit_id': '52fe44509251416c750305a1', 'de...   35431113
# 2958  [{'credit_id': '57bfd2089251414b1500001e', 'de...   22730842
# 2959  [{'credit_id': '537ef0d8c3a36805a1002844', 'de...    4600000
#
# [10 rows x 23 columns]

# %%
read_imdb_data.iloc[ [3,6,9],  [3,6,7] ] # Custom Indexes
# Out:
#                                               genres original_language  \
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...                en
#
#    original_title
# 3         Kahaani
# 6  The Possession
# 9   A Mighty Wind

# %%
# [True,True]+[False]*2998 # 3000 rows

# %%
read_imdb_data.shape
# Out:
# (3000, 23)

# %%
## Boolean Index
# Use of conditional and logical operator
list_boolean = [True,False,True]+[False]*2997
read_imdb_data.loc[list_boolean,] # Understand this interesting concept
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2   3                                                NaN   3300000
#
#                            genres                           homepage  \
# 0  [{'id': 35, 'name': 'Comedy'}]                                NaN
# 2   [{'id': 18, 'name': 'Drama'}]  http://sonyclassics.com/whiplash/
#
#      imdb_id original_language          original_title  \
# 0  tt2637294                en  Hot Tub Time Machine 2
# 2  tt2582802                en                Whiplash
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
# 2    The road to greatness can take you to the edge.                Whiplash
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
#
# [2 rows x 23 columns]

# %%
read_imdb_data.head(5)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df
# Out:
#     name  age
# A   John   28
# B  David   20
# C   Reva   32
# D  Grahm   40

# %%
df.loc[ [True,False, False, True] , ]
# Out:
#     name  age
# A   John   28
# D  Grahm   40

# %%
df.iloc[ [True,False,True,True] , ]
# Out:
#     name  age
# A   John   28
# C   Reva   32
# D  Grahm   40

# %%
filter_boolean = read_imdb_data.loc[:,['runtime']] > 120
print(filter_boolean)
# Out:
#       runtime
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# ...       ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
#
# [3000 rows x 1 columns]

# %%
filter_boolean['runtime']
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: runtime, Length: 3000, dtype: bool

# %%
filter_boolean = read_imdb_data.loc[:,['runtime']] > 120
read_imdb_data_120plus = read_imdb_data.loc[filter_boolean['runtime'],] # Conditional Subsetting

# %%
# read_imdb_data_120plus.head()

# %%
# ~[True, False, True] --> [False, True, False]

# %%
read_imdb_data.loc[~filter_boolean['runtime'],] # Reverse Conditional Subsetting
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 4        5                                                NaN         0
# 5        6                                                NaN   8000000
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 4                                   NaN  tt1380152                ko
# 5                                   NaN  tt0093743                en
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 4                                         마린보이
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# 5     Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 0         2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1          8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2        10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4          2/5/09   118.0  [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 5          8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...           ...     ...                                       ...       ...
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996      3/28/13   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 4                                   Marine Boy
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 5     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [2343 rows x 23 columns]

# %%
# Multiple conditions
condition1 = read_imdb_data.loc[:,['runtime']] > 120
condition2 = read_imdb_data.loc[:,['original_language']] =='en'
# read_imdb_data.loc[condition1['runtime'] & condition2['original_language'],] # and condition - Note : here & is used not 'and'
read_imdb_data.loc[condition1['runtime'] | condition2['original_language'],] # or condition - Note : here | is used not 'or'
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 5        6                                                NaN   8000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# ...                                                 ...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 5                                   NaN  tt0093743                en
# ...                                 ...        ...               ...
# 2994                                NaN  tt0105327                en
# 2995                                NaN  tt0109403                en
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 5     Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# ...                                                 ...         ...  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 5          8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...           ...     ...                                                ...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 5     Released                                                NaN
# ...        ...                                                ...
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 5                                                   NaN
# ...                                                 ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# ...                                                 ...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 5     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# ...                                                 ...        ...
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [2726 rows x 23 columns]

# %%
# Important Points to remember :
# iloc vs loc
# --> loc : Index& columns names , iloc : Index number and Column number is considered
# --> loc : Range (a:b) , b is included, iloc:Range (a:b) , b is excluded

# %% [markdown]
# ### Creating new columns, renaming & droping

# %% [markdown]
# #### Rename

# %%
# dataframe.rename(columns={'column_name':'new_column_name'},inplace=True) # Syntax

# %%
read_imdb_data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# read_imdb_data.rename(columns = {'budget':'movie_budget','cast':'movie_cast'})
read_imdb_data.rename(columns = {'budget':'movie_budget','cast':'movie_cast'}, inplace= True)

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection  movie_budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...      14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                           movie_cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %% [markdown]
# #### New Columns

# %%
# read_imdb_data['runtime'] #-- This feature is going to be removed

# %%
read_imdb_data.loc[:,'half_runtime'] = read_imdb_data.loc[:, 'runtime'] * 0.5
read_imdb_data
# Out:
#         id                              belongs_to_collection  movie_budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...      14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...      40000000
# 2        3                                                NaN       3300000
# 3        4                                                NaN       1200000
# 4        5                                                NaN             0
# ...    ...                                                ...           ...
# 2995  2996                                                NaN             0
# 2996  2997                                                NaN             0
# 2997  2998                                                NaN      65000000
# 2998  2999                                                NaN      42000000
# 2999  3000                                                NaN      35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      runtime                                   spoken_languages    status  \
# 0       93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2      105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3      122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4      118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# ...      ...                                                ...       ...
# 2995   102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997   120.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                              movie_cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime
# 0            46.5
# 1            56.5
# 2            52.5
# 3            61.0
# 4            59.0
# ...           ...
# 2995         51.0
# 2996         51.0
# 2997         60.0
# 2998         45.0
# 2999         53.0
#
# [3000 rows x 24 columns]

# %%
read_imdb_data.loc[:,'revenue_runtime_ratio'] = (read_imdb_data.loc[:, 'revenue'] / read_imdb_data.loc[:, 'runtime'])
read_imdb_data
# Out:
#         id                              belongs_to_collection  movie_budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...      14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...      40000000
# 2        3                                                NaN       3300000
# 3        4                                                NaN       1200000
# 4        5                                                NaN             0
# ...    ...                                                ...           ...
# 2995  2996                                                NaN             0
# 2996  2997                                                NaN             0
# 2997  2998                                                NaN      65000000
# 2998  2999                                                NaN      42000000
# 2999  3000                                                NaN      35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                        spoken_languages    status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4              [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# ...                                                 ...       ...
# 2995           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                              movie_cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime revenue_runtime_ratio
# 0            46.5          1.324156e+05
# 1            56.5          8.420304e+05
# 2            52.5          1.246857e+05
# 3            61.0          1.311475e+05
# 4            59.0          3.325398e+04
# ...           ...                   ...
# 2995         51.0          1.565379e+04
# 2996         51.0          1.770490e+03
# 2997         60.0          7.454730e+05
# 2998         45.0          1.910704e+06
# 2999         53.0          7.744071e+05
#
# [3000 rows x 25 columns]

# %%
read_imdb_data['check'] = list(range(1,3001))

# %%
# len(list(range(1,3001)))

# %%
read_imdb_data.head()
# Out:
#    id                              belongs_to_collection  movie_budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...      14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...      40000000
# 2   3                                                NaN       3300000
# 3   4                                                NaN       1200000
# 4   5                                                NaN             0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                           movie_cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   revenue_runtime_ratio check
# 0         132415.602151     1
# 1         842030.398230     2
# 2         124685.714286     3
# 3         131147.540984     4
# 4          33253.983051     5
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Drop columns & rows

# %%
read_imdb_data.drop(['check'],axis = 1, inplace = True) # Drop column
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection  movie_budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...      14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                          spoken_languages    status  \
# 0    6.575393  ...  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                           movie_cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
#
#   revenue_runtime_ratio
# 0         132415.602151
#
# [1 rows x 25 columns]

# %%
read_imdb_data.drop([0,1,2], axis = 0) # Drop rows
# Out:
#         id belongs_to_collection  movie_budget  \
# 3        4                   NaN       1200000
# 4        5                   NaN             0
# 5        6                   NaN       8000000
# 6        7                   NaN      14000000
# 7        8                   NaN             0
# ...    ...                   ...           ...
# 2995  2996                   NaN             0
# 2996  2997                   NaN             0
# 2997  2998                   NaN      65000000
# 2998  2999                   NaN      42000000
# 2999  3000                   NaN      35000000
#
#                                                  genres  \
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                   [{'id': 99, 'name': 'Documentary'}]
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                 homepage    imdb_id original_language  \
# 3             http://kahaanithefilm.com/  tt1821480                hi
# 4                                    NaN  tt1380152                ko
# 5                                    NaN  tt0093743                en
# 6     http://www.thepossessionmovie.com/  tt0431021                en
# 7                                    NaN  tt0391024                en
# ...                                  ...        ...               ...
# 2995                                 NaN  tt0109403                en
# 2996                                 NaN  tt2364975                sv
# 2997                                 NaN  tt0116908                en
# 2998      http://www.alongcamepolly.com/  tt0343135                en
# 2999    http://www.abductionthefilm.com/  tt1600195                en
#
#                               original_title  \
# 3                                    Kahaani
# 4                                       마린보이
# 5     Pinocchio and the Emperor of the Night
# 6                             The Possession
# 7                               Control Room
# ...                                      ...
# 2995                                 Chasers
# 2996                             Vi är bäst!
# 2997                 The Long Kiss Goodnight
# 2998                        Along Came Polly
# 2999                               Abduction
#
#                                                overview  popularity  ...  \
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# 5     Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6     A young girl buys an antique box at a yard sal...    7.286477  ...
# 7     A chronicle which provides a rare window into ...    1.949044  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                        spoken_languages    status  \
# 3     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4              [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 5              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7     [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# ...                                                 ...       ...
# 2995           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                  Fear The Demon That Doesn't Fear God
# 7                 Different channels. Different truths.
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                        title  \
# 3                                    Kahaani
# 4                                 Marine Boy
# 5     Pinocchio and the Emperor of the Night
# 6                             The Possession
# 7                               Control Room
# ...                                      ...
# 2995                                 Chasers
# 2996                        We Are the Best!
# 2997                 The Long Kiss Goodnight
# 2998                        Along Came Polly
# 2999                               Abduction
#
#                                                Keywords  \
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7     [{'id': 917, 'name': 'journalism'}, {'id': 163...
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                              movie_cast  \
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6     [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7     [{'cast_id': 2, 'character': 'Himself', 'credi...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 5     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# 6     [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075
# 7     [{'credit_id': '52fe47a69251416c750a0daf', 'de...    2586511
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime revenue_runtime_ratio
# 3            61.0          1.311475e+05
# 4            59.0          3.325398e+04
# 5            41.5          3.929684e+04
# 6            46.0          9.287617e+05
# 7            42.0          3.079180e+04
# ...           ...                   ...
# 2995         51.0          1.565379e+04
# 2996         51.0          1.770490e+03
# 2997         60.0          7.454730e+05
# 2998         45.0          1.910704e+06
# 2999         53.0          7.744071e+05
#
# [2997 rows x 25 columns]

# %%
# .drop : names of index or column, axis default is 0

# %% [markdown]
# ### Handling Missing Values

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
# Identify, Drop or fill
# isna(),dropna(), fillna()

# %%
3000-604
# Out:
# 2396

# %%
read_imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
read_imdb_data.loc[:,'belongs_to_collection'].head(10)
# Out:
# 0    [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1    [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8    [{'id': 256377, 'name': 'The Muppet Collection...
# 9                                                  NaN
# Name: belongs_to_collection, dtype: object

# %%
sum(read_imdb_data.loc[:,'belongs_to_collection'].isna())/read_imdb_data.shape[0]
# Out:
# 0.7986666666666666

# %%
read_imdb_data.loc[:,'belongs_to_collection'].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# Name: belongs_to_collection, Length: 3000, dtype: bool

# %%
read_imdb_data.belongs_to_collection.isna() #Method 1
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# Name: belongs_to_collection, Length: 3000, dtype: bool

# %%
read_imdb_data['belongs_to_collection'].isna() # Method 2
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# Name: belongs_to_collection, Length: 3000, dtype: bool

# %%
read_imdb_data.loc[:,'belongs_to_collection'].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# Name: belongs_to_collection, Length: 3000, dtype: bool

# %%
# Identify - subset the data as per the null values
read_imdb_data.loc[read_imdb_data.belongs_to_collection.isna(),].head(2)
# Out:
#    id belongs_to_collection   budget  \
# 2   3                   NaN  3300000
# 3   4                   NaN  1200000
#
#                                               genres  \
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             homepage    imdb_id original_language  \
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
#
#   original_title                                           overview  \
# 2       Whiplash  Under the direction of a ruthless instructor, ...
# 3        Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
#
#    popularity  ... release_date runtime  \
# 2   64.299990  ...     10/10/14   105.0
# 3    3.174936  ...       3/9/12   122.0
#
#                                     spoken_languages    status  \
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                            tagline     title  \
# 2  The road to greatness can take you to the edge.  Whiplash
# 3                                              NaN   Kahaani
#
#                                             Keywords  \
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
#
#                                                 cast  \
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
#
#                                                 crew   revenue
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
#
# [2 rows x 23 columns]

# %%
read_imdb_data.dropna() # Remove all rows having Na anywhere
# Out:
#         id                              belongs_to_collection     budget  \
# 22      23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69      70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
# ...    ...                                                ...        ...
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...   25000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                  genres  \
# 22    [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40    [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46    [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                 ...
# 2904  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2927  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2938  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2968  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2984  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                                homepage    imdb_id  \
# 22                  http://www.magnetreleasing.com/vhs/  tt2105044
# 40    http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# 46    http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 60    http://www.mgm.com/#/our-titles/233/Casino-Roy...  tt0381061
# 69                http://www.thefastandthefurious3.com/  tt0463985
# ...                                                 ...        ...
# 2904        http://www.miramax.com/movie/trainspotting/  tt0117951
# 2927  http://www.mgm.com/view/movie/232/Die-Another-...  tt0246460
# 2938                  http://www.projectprometheus.com/  tt1446714
# 2968  http://www.bloodrayne-themovie.com/main/index....  tt0383222
# 2984        http://www.sonypictures.com/homevideo/swat/  tt0257076
#
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity  ...  \
# 22    When a group of misfits is hired by an unknown...    7.820787  ...
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626  ...
# 46    Diego, Manny and Sid return in this sequel to ...   16.646029  ...
# 60    Le Chiffre, a banker to the world's terrorists...   23.065078  ...
# 69    In order to avoid a jail sentence, Sean Boswel...    2.238808  ...
# ...                                                 ...         ...  ...
# 2904  Renton, deeply immersed in the Edinburgh drug ...   19.348466  ...
# 2927  Bond takes on a North Korean leader who underg...   12.996474  ...
# 2938  A team of explorers discover a clue to the ori...   16.624854  ...
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132  ...
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952  ...
#
#      release_date runtime                                   spoken_languages  \
# 22        7/28/12   116.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40        4/26/06   118.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 46        3/23/06    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 60       11/14/06   144.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 69         6/3/06   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...           ...     ...                                                ...
# 2904      2/23/96    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2927     11/17/02   133.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2938      5/30/12   124.0  [{'iso_639_1': 'gd', 'name': ''}, {'iso_639_1'...
# 2968     10/22/05    95.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2984       8/8/03   117.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#         status                                            tagline  \
# 22    Released                         This collection is killer.
# 40    Released  How Miami became the cocaine capital of the Un...
# 46    Released                       The Ice age is melting away.
# 60    Released  Everyone has a past. Every legend has a beginn...
# 69    Released  On the streets of Tokyo, speed needs no transl...
# ...        ...                                                ...
# 2904  Released                                       Choose life.
# 2927  Released                            He’s never been cooler.
# 2938  Released  The Search for Our Beginning Could Lead to Our...
# 2968  Released                     Revenge never tasted so sweet.
# 2984  Released              You're either S.W.A.T. or you're not.
#
#                                       title  \
# 22                                    V/H/S
# 40                          Cocaine Cowboys
# 46                    Ice Age: The Meltdown
# 60                            Casino Royale
# 69    The Fast and the Furious: Tokyo Drift
# ...                                     ...
# 2904                          Trainspotting
# 2927                        Die Another Day
# 2938                             Prometheus
# 2968                             BloodRayne
# 2984                               S.W.A.T.
#
#                                                Keywords  \
# 22    [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 40    [{'id': 2150, 'name': 'cocaine'}, {'id': 2231,...
# 46    [{'id': 2078, 'name': 'mammoth'}, {'id': 2079,...
# 60    [{'id': 131, 'name': 'italy'}, {'id': 383, 'na...
# 69    [{'id': 830, 'name': 'car race'}, {'id': 1926,...
# ...                                                 ...
# 2904  [{'id': 212, 'name': 'london england'}, {'id':...
# 2927  [{'id': 3290, 'name': 'laser'}, {'id': 156095,...
# 2938  [{'id': 803, 'name': 'android'}, {'id': 4565, ...
# 2968  [{'id': 3133, 'name': 'vampire'}, {'id': 9259,...
# 2984  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
#
#                                                    cast  \
# 22    [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 40    [{'cast_id': 2, 'character': 'Himself', 'credi...
# 46    [{'cast_id': 1, 'character': 'Manny (voice)', ...
# 60    [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 69    [{'cast_id': 12, 'character': 'Sean Boswell', ...
# ...                                                 ...
# 2904  [{'cast_id': 17, 'character': 'Mark Renton', '...
# 2927  [{'cast_id': 20, 'character': 'James Bond', 'c...
# 2938  [{'cast_id': 5, 'character': 'Dr. Elizabeth Sh...
# 2968  [{'cast_id': 3, 'character': 'Rayne', 'credit_...
# 2984  [{'cast_id': 25, 'character': "Sgt. Dan 'Hondo...
#
#                                                    crew    revenue
# 22    [{'credit_id': '52fe48ee9251416c9109d113', 'de...     100345
# 40    [{'credit_id': '52fe46179251416c7506cc15', 'de...     163000
# 46    [{'credit_id': '52fe4292c3a36847f80292c9', 'de...  660940780
# 60    [{'credit_id': '53ac1fd7c3a3684bc8001908', 'de...  599045960
# 69    [{'credit_id': '56784ed792514111900002c8', 'de...  158468292
# ...                                                 ...        ...
# 2904  [{'credit_id': '52fe4260c3a36847f80198c1', 'de...   16491080
# 2927  [{'credit_id': '52fe45ff9251416c91045a7f', 'de...  431971116
# 2938  [{'credit_id': '52fe481dc3a368484e0e9db7', 'de...  403170142
# 2968  [{'credit_id': '52fe4cd4c3a36847f82407f7', 'de...    2405420
# 2984  [{'credit_id': '5379d4980e0a261431006f58', 'de...  116643346
#
# [203 rows x 23 columns]

# %%
read_imdb_data.shape
# Out:
# (3000, 23)

# %%
# read_imdb_data.loc[~read_imdb_data.loc[:,'belongs_to_collection'].isna(),]

# %%
# fillna()
read_imdb_data_copy = read_imdb_data.copy()

# %%
# Full data impute with some value
read_imdb_data_copy.fillna('Value not available')
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                Value not available   3300000
# 3        4                                Value not available   1200000
# 4        5                                Value not available         0
# ...    ...                                                ...       ...
# 2995  2996                                Value not available         0
# 2996  2997                                Value not available         0
# 2997  2998                                Value not available  65000000
# 2998  2999                                Value not available  42000000
# 2999  3000                                Value not available  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                   Value not available  tt2637294                en
# 1                   Value not available  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                   Value not available  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                Value not available  tt0109403                en
# 2996                Value not available  tt2364975                sv
# 2997                Value not available  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                Value not available
# 4     Released                                Value not available
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                Value not available
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                   Value not available
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 23 columns]

# %%
# Fillna on specific column
read_imdb_data_copy.belongs_to_collection = read_imdb_data_copy.belongs_to_collection.fillna(' Missing Value')

# %%
read_imdb_data_copy.head(5)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                      Missing Value   3300000
# 3   4                                      Missing Value   1200000
# 4   5                                      Missing Value         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
(60+62+98)/3
# Out:
# 73.33333333333333

# %%
# Fill the null value
# Categorical - 'Missing'/'Others'/Most frequent value
# Continous - mean / median

# %%
# Visualisation --: Outlier

# %% [markdown]
# ### Sorting & Handling Duplicates

# %%
# Sorting : sort_values

# %%
# Creating a DataFrame
data = {'A': [1, 3, 2, 1, 2],
        'B': ['a', 'b', 'c', 'a', 'b'],
        'C':[0, 1, 9, 0, 2]}
df = pd.DataFrame(data)
df
# Out:
#    A  B  C
# 0  1  a  0
# 1  3  b  1
# 2  2  c  9
# 3  1  a  0
# 4  2  b  2

# %%
# Sorting by column A
df_sorted = df.sort_values(by='A') # default ascending

print(df_sorted)
# Out:
#    A  B  C
# 0  1  a  0
# 3  1  a  0
# 2  2  c  9
# 4  2  b  2
# 1  3  b  1

# %%
# Sorting by column A -  Descending
df.sort_values(by='A', ascending = False)
# Out:
#    A  B  C
# 1  3  b  1
# 2  2  c  9
# 4  2  b  2
# 0  1  a  0
# 3  1  a  0

# %%
# Sorting by column A & Column B
df.sort_values(by= ['A','B'], ascending = [False,False])
# Out:
#    A  B  C
# 1  3  b  1
# 2  2  c  9
# 4  2  b  2
# 0  1  a  0
# 3  1  a  0

# %%
df.sort_values(by= ['A','B'], ascending = [False,True])
# Out:
#    A  B  C
# 1  3  b  1
# 4  2  b  2
# 2  2  c  9
# 0  1  a  0
# 3  1  a  0

# %%
df.sort_values(by= ['B','A'], ascending = [False,True])
# Out:
#    A  B  C
# 2  2  c  9
# 4  2  b  2
# 1  3  b  1
# 0  1  a  0
# 3  1  a  0

# %%
# Sorting by column A & Column B : A Ascending & B descending
df.sort_values(by=['A','B'], ascending = [True,False])
# Out:
#    A  B  C
# 0  1  a  0
# 3  1  a  0
# 2  2  c  9
# 4  2  b  2
# 1  3  b  1

# %%
# Implement it on IMDB data
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
# read_imdb_data.sort_values(by = 'runtime',ascending  = False)

# %%
df
# Out:
#    A  B  C
# 0  1  a  0
# 1  3  b  1
# 2  2  c  9
# 3  1  a  0
# 4  2  b  2

# %%
# groupby([all columns])['id'].count()

# %%
df.loc[:,['A','B']].value_counts().reset_index()
# Out:
#    A  B  count
# 0  1  a      2
# 1  2  b      1
# 2  2  c      1
# 3  3  b      1

# %%
sum(df.value_counts().reset_index()['count']>1)
# Out:
# 1

# %%
## value_counts() : Count the value # and create the column count.
sum(df.value_counts().reset_index()['count']>1) # How many rows are there having duplicated values?
# Out:
# 1

# %%
# Convert it dataframe format
df.value_counts().reset_index()
# Out:
#    A  B  C  count
# 0  1  a  0      2
# 1  2  b  2      1
# 2  2  c  9      1
# 3  3  b  1      1

# %%
read_imdb_data_dup = pd.concat([read_imdb_data,read_imdb_data.iloc[40:50,:]]) # Created the duplicate records

# %%
read_imdb_data_dup.value_counts().reset_index().sort_values('count',ascending = False)
# Out:
#        id                              belongs_to_collection     budget  \
# 0      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 1      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 201  1116  [{'id': 645, 'name': 'James Bond Collection', ...   14000000
# 138   208  [{'id': 286162, 'name': 'Power Rangers Collect...   15000000
# 128   539  [{'id': 84, 'name': 'Indiana Jones Collection'...   48000000
# ..    ...                                                ...        ...
# 70   2891  [{'id': 14563, 'name': 'The Ring Collection', ...   25000000
# 71   2892  [{'id': 479888, 'name': 'The Thing Collection'...   35000000
# 72   2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 73   2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 202  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                 genres  \
# 0    [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 1    [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 201  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 138  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 128  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..                                                 ...
# 70                      [{'id': 27, 'name': 'Horror'}]
# 71   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 72   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 73   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 202  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                               homepage    imdb_id  \
# 0    http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# 1    http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 201  http://www.mgm.com/view/movie/1891/The-Spy-Who...  tt0076752
# 138                       http://www.powerrangers.com/  tt0113820
# 128                http://www.indianajones.com/crusade  tt0097576
# ..                                                 ...        ...
# 70                          http://www.ringsmovie.com/  tt0498381
# 71           http://www.uphe.com/movies/the-thing-2011  tt0905372
# 72         http://www.miramax.com/movie/trainspotting/  tt0117951
# 73   http://www.mgm.com/view/movie/232/Die-Another-...  tt0246460
# 202        http://www.sonypictures.com/homevideo/swat/  tt0257076
#
#     original_language                           original_title  \
# 0                  en                          Cocaine Cowboys
# 1                  en                    Ice Age: The Meltdown
# 201                en                     The Spy Who Loved Me
# 138                en  Mighty Morphin Power Rangers: The Movie
# 128                en       Indiana Jones and the Last Crusade
# ..                ...                                      ...
# 70                 en                                    Rings
# 71                 en                                The Thing
# 72                 en                            Trainspotting
# 73                 en                          Die Another Day
# 202                en                                 S.W.A.T.
#
#                                               overview  popularity  ...  \
# 0    In the 1980s, ruthless Colombian cocaine baron...    2.941626  ...
# 1    Diego, Manny and Sid return in this sequel to ...   16.646029  ...
# 201  Russian and British submarines with nuclear mi...    9.781451  ...
# 138  Power up with six incredible teens who out-man...    7.024227  ...
# 128  When Dr. Henry Jones Sr. suddenly goes missing...   14.788987  ...
# ..                                                 ...         ...  ...
# 70   Julia becomes worried about her boyfriend, Hol...   24.535733  ...
# 71   When paleontologist Kate Lloyd travels to an i...   10.169411  ...
# 72   Renton, deeply immersed in the Edinburgh drug ...   19.348466  ...
# 73   Bond takes on a North Korean leader who underg...   12.996474  ...
# 202  Hondo Harrelson recruits Jim Street to join an...   13.334952  ...
#
#     runtime                                   spoken_languages    status  \
# 0     118.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      91.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 201   125.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 138    92.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 128   127.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# ..      ...                                                ...       ...
# 70    102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 71    103.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 72     93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 73    133.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 202   117.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                tagline  \
# 0    How Miami became the cocaine capital of the Un...
# 1                         The Ice age is melting away.
# 201  It's the BIGGEST. It's the BEST. It's BOND. An...
# 138                                   The Power Is On!
# 128  The man with the hat is back. And this time, h...
# ..                                                 ...
# 70                                     Evil is reborn.
# 71                                It's Not Human. Yet.
# 72                                        Choose life.
# 73                             He’s never been cooler.
# 202              You're either S.W.A.T. or you're not.
#
#                                        title  \
# 0                            Cocaine Cowboys
# 1                      Ice Age: The Meltdown
# 201                     The Spy Who Loved Me
# 138  Mighty Morphin Power Rangers: The Movie
# 128       Indiana Jones and the Last Crusade
# ..                                       ...
# 70                                     Rings
# 71                                 The Thing
# 72                             Trainspotting
# 73                           Die Another Day
# 202                                 S.W.A.T.
#
#                                               Keywords  \
# 0    [{'id': 2150, 'name': 'cocaine'}, {'id': 2231,...
# 1    [{'id': 2078, 'name': 'mammoth'}, {'id': 2079,...
# 201  [{'id': 212, 'name': 'london england'}, {'id':...
# 138  [{'id': 10988, 'name': 'based on tv series'}, ...
# 128  [{'id': 83, 'name': 'saving the world'}, {'id'...
# ..                                                 ...
# 70   [{'id': 3298, 'name': 'hallucination'}, {'id':...
# 71   [{'id': 2340, 'name': 'paranoia'}, {'id': 4713...
# 72   [{'id': 212, 'name': 'london england'}, {'id':...
# 73   [{'id': 3290, 'name': 'laser'}, {'id': 156095,...
# 202  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
#
#                                                   cast  \
# 0    [{'cast_id': 2, 'character': 'Himself', 'credi...
# 1    [{'cast_id': 1, 'character': 'Manny (voice)', ...
# 201  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 138  [{'cast_id': 2, 'character': 'Kimberly Hart / ...
# 128  [{'cast_id': 8, 'character': 'Indiana Jones', ...
# ..                                                 ...
# 70   [{'cast_id': 14, 'character': 'Julia', 'credit...
# 71   [{'cast_id': 2, 'character': 'Kate Lloyd', 'cr...
# 72   [{'cast_id': 17, 'character': 'Mark Renton', '...
# 73   [{'cast_id': 20, 'character': 'James Bond', 'c...
# 202  [{'cast_id': 25, 'character': "Sgt. Dan 'Hondo...
#
#                                                   crew    revenue count
# 0    [{'credit_id': '52fe46179251416c7506cc15', 'de...     163000     2
# 1    [{'credit_id': '52fe4292c3a36847f80292c9', 'de...  660940780     2
# 201  [{'credit_id': '52fe426bc3a36847f801d187', 'de...  185438673     1
# 138  [{'credit_id': '52fe44d8c3a36847f80ad707', 'de...   66000000     1
# 128  [{'credit_id': '52fe4216c3a36847f8002e69', 'de...  474171806     1
# ..                                                 ...        ...   ...
# 70   [{'credit_id': '52fe46019251416c75069e25', 'de...   83080890     1
# 71   [{'credit_id': '537b713fc3a3682d3c00000e', 'de...   28128670     1
# 72   [{'credit_id': '52fe4260c3a36847f80198c1', 'de...   16491080     1
# 73   [{'credit_id': '52fe45ff9251416c91045a7f', 'de...  431971116     1
# 202  [{'credit_id': '5379d4980e0a261431006f58', 'de...  116643346     1
#
# [203 rows x 24 columns]

# %%
# Convert it dataframe format
df.value_counts().reset_index().sort_values('count')
# Out:
#    A  B  C  count
# 1  2  b  2      1
# 2  2  c  9      1
# 3  3  b  1      1
# 0  1  a  0      2

# %%
df['B'].value_counts().reset_index()
# Out:
#    B  count
# 0  a      2
# 1  b      2
# 2  c      1

# %%
df
# Out:
#    A  B  C
# 0  1  a  0
# 1  3  b  1
# 2  2  c  9
# 3  1  a  0
# 4  2  b  2

# %%
# Drop duplicates
# .drop_duplicates() , subset & keep parameters
df.drop_duplicates() # Drop duplicates for the dataframe # Load the data in dataframe.
# Out:
#    A  B  C
# 0  1  a  0
# 1  3  b  1
# 2  2  c  9
# 4  2  b  2

# %%
df.sort_values(by = 'A') # Column A as customer
# Out:
#    A  B  C
# 0  1  a  0
# 3  1  a  0
# 2  2  c  9
# 4  2  b  2
# 1  3  b  1

# %%
df
# Out:
#    A  B  C
# 0  1  a  0
# 1  3  b  1
# 2  2  c  9
# 3  1  a  0
# 4  2  b  2

# %%
df.drop_duplicates(subset = ['A','B'], keep = 'last')
# Out:
#    A  B  C
# 1  3  b  1
# 2  2  c  9
# 3  1  a  0
# 4  2  b  2

# %%
# Last : latest
# First : first punched :: issue with API, Database

# %% [markdown]
# ### Aggregating Data

# %%
# .groupby(), .agg()

# sum(): Computes the sum of all values in a series or dataframe.
# mean(): Computes the mean (average) of all values in a series or dataframe.
# median(): Computes the median (middle value) of all values in a series or dataframe.
# min(): Computes the minimum value in a series or dataframe.
# max(): Computes the maximum value in a series or dataframe.
# count(): Computes the number of non-null values in a series or dataframe.

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
# read_imdb_data.loc[:,'runtime'].sum()
# read_imdb_data['mean_runtime'] = read_imdb_data.runtime.mean()

# %%
# pd.mean(read_imdb_data['runtime'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-9a8e1f38daff> in <cell line: 1>()
# ----> 1 pd.mean(read_imdb_data['runtime'])
#
# AttributeError: module 'pandas' has no attribute 'mean'

# %%
sum(list(read_imdb_data['runtime'].fillna(0)))
# Out:
# 323354.0

# %% [markdown]
# #### .groupby()

# %%
read_imdb_data.groupby('original_language')['id'].count().reset_index().sort_values(by = 'id', ascending =False)
# Out:
#    original_language    id
# 7                 en  2575
# 11                fr    78
# 27                ru    47
# 8                 es    43
# 13                hi    42
# 17                ja    37
# 16                it    24
# 18                ko    20
# 2                 cn    20
# 35                zh    19
# 5                 de    18
# 30                ta    16
# 29                sv     8
# 25                pt     6
# 22                nl     6
# 9                 fa     5
# 4                 da     5
# 26                ro     4
# 32                tr     3
# 14                hu     3
# 10                fi     2
# 31                te     2
# 24                pl     2
# 23                no     2
# 19                ml     2
# 21                nb     1
# 20                mr     1
# 3                 cs     1
# 28                sr     1
# 1                 bn     1
# 15                id     1
# 6                 el     1
# 12                he     1
# 33                ur     1
# 34                vi     1
# 0                 ar     1

# %%
read_imdb_data.groupby('original_language')['runtime'].mean().reset_index().sort_values(by='runtime',ascending = False)
# Out:
#    original_language     runtime
# 20                mr  162.000000
# 30                ta  159.875000
# 15                id  150.000000
# 13                hi  148.880952
# 31                te  146.000000
# 19                ml  137.000000
# 34                vi  135.000000
# 14                hu  126.000000
# 1                 bn  125.000000
# 29                sv  122.375000
# 5                 de  122.294118
# 35                zh  121.368421
# 32                tr  119.000000
# 18                ko  115.100000
# 25                pt  114.666667
# 17                ja  112.972973
# 26                ro  108.750000
# 22                nl  107.333333
# 7                 en  106.984078
# 11                fr  106.294872
# 2                 cn  105.450000
# 4                 da  105.400000
# 21                nb  103.000000
# 8                 es  100.372093
# 10                fi  100.000000
# 24                pl   99.000000
# 0                 ar   98.000000
# 28                sr   97.000000
# 9                 fa   96.400000
# 27                ru   95.586957
# 23                no   95.500000
# 33                ur   94.000000
# 16                it   91.625000
# 6                 el   91.000000
# 3                 cs   90.000000
# 12                he   90.000000

# %%
read_imdb_data.groupby('original_language')['revenue'].mean().reset_index().sort_values(by='revenue',ascending = False)
# Out:
#    original_language       revenue
# 7                 en  7.466591e+07
# 35                zh  7.037637e+07
# 32                tr  5.166341e+07
# 17                ja  3.065180e+07
# 2                 cn  2.977289e+07
# 13                hi  2.534637e+07
# 5                 de  2.053090e+07
# 11                fr  1.713257e+07
# 16                it  1.641513e+07
# 24                pl  1.501083e+07
# 30                ta  1.470625e+07
# 18                ko  1.377670e+07
# 4                 da  1.175709e+07
# 29                sv  1.163051e+07
# 12                he  1.112585e+07
# 25                pt  1.087902e+07
# 8                 es  8.564790e+06
# 31                te  8.320425e+06
# 6                 el  8.000000e+06
# 27                ru  6.929453e+06
# 20                mr  4.400000e+06
# 21                nb  4.159678e+06
# 15                id  2.627209e+06
# 22                nl  1.959667e+06
# 10                fi  1.471932e+06
# 0                 ar  1.347747e+06
# 19                ml  1.315000e+06
# 23                no  1.011068e+06
# 9                 fa  7.121852e+05
# 33                ur  6.451350e+05
# 34                vi  6.390000e+05
# 1                 bn  5.363640e+05
# 26                ro  3.399610e+05
# 14                hu  1.247927e+05
# 3                 cs  1.739300e+04
# 28                sr  1.980000e+02

# %%
read_imdb_data.groupby('status')['id'].count()
# Out:
# status
# Released    2996
# Rumored        4
# Name: id, dtype: int64

# %%
# Rows where status = Rumored
# read_imdb_data.loc[read_imdb_data.status =='Rumored',]

# %%
read_imdb_data.groupby(['original_language','status'])['id'].count().reset_index()

# %% [markdown]
# #### .agg()

# %%
# .agg()
read_imdb_data.groupby(['original_language','status'])['runtime'].agg(['count','mean','sum']).reset_index()
# Out:
#    original_language    status  count        mean       sum
# 0                 ar  Released      1   98.000000      98.0
# 1                 bn  Released      1  125.000000     125.0
# 2                 cn  Released     20  105.450000    2109.0
# 3                 cs  Released      1   90.000000      90.0
# 4                 da  Released      5  105.400000     527.0
# 5                 de  Released     17  122.294118    2079.0
# 6                 el  Released      1   91.000000      91.0
# 7                 en  Released   2571  107.030338  275175.0
# 8                 en   Rumored      4   77.250000     309.0
# 9                 es  Released     43  100.372093    4316.0
# 10                fa  Released      5   96.400000     482.0
# 11                fi  Released      2  100.000000     200.0
# 12                fr  Released     78  106.294872    8291.0
# 13                he  Released      1   90.000000      90.0
# 14                hi  Released     42  148.880952    6253.0
# 15                hu  Released      3  126.000000     378.0
# 16                id  Released      1  150.000000     150.0
# 17                it  Released     24   91.625000    2199.0
# 18                ja  Released     37  112.972973    4180.0
# 19                ko  Released     20  115.100000    2302.0
# 20                ml  Released      2  137.000000     274.0
# 21                mr  Released      1  162.000000     162.0
# 22                nb  Released      1  103.000000     103.0
# 23                nl  Released      6  107.333333     644.0
# 24                no  Released      2   95.500000     191.0
# 25                pl  Released      2   99.000000     198.0
# 26                pt  Released      6  114.666667     688.0
# 27                ro  Released      4  108.750000     435.0
# 28                ru  Released     46   95.586957    4397.0
# 29                sr  Released      1   97.000000      97.0
# 30                sv  Released      8  122.375000     979.0
# 31                ta  Released     16  159.875000    2558.0
# 32                te  Released      2  146.000000     292.0
# 33                tr  Released      3  119.000000     357.0
# 34                ur  Released      1   94.000000      94.0
# 35                vi  Released      1  135.000000     135.0
# 36                zh  Released     19  121.368421    2306.0

# %%
read_imdb_data.groupby(['status', 'original_language']).agg({'runtime':"mean",'revenue': "max",'imdb_id':"count"}).reset_index()
# Out:
#       status original_language     runtime     revenue  imdb_id
# 0   Released                ar   98.000000     1347747        1
# 1   Released                bn  125.000000      536364        1
# 2   Released                cn  105.450000   156844753       20
# 3   Released                cs   90.000000       17393        1
# 4   Released                da  105.400000    42070000        5
# 5   Released                de  122.294118    92180910       18
# 6   Released                el   91.000000     8000000        1
# 7   Released                en  107.030338  1519557910     2571
# 8   Released                es  100.372093    67872296       43
# 9   Released                fa   96.400000     2402067        5
# 10  Released                fi  100.000000     2411594        2
# 11  Released                fr  106.294872   426480871       78
# 12  Released                he   90.000000    11125849        1
# 13  Released                hi  148.880952   310000000       42
# 14  Released                hu  126.000000      282358        3
# 15  Released                id  150.000000     2627209        1
# 16  Released                it   91.625000   229400000       24
# 17  Released                ja  112.972973   133949270       37
# 18  Released                ko  115.100000    86758912       20
# 19  Released                ml  137.000000     2500000        2
# 20  Released                mr  162.000000     4400000        1
# 21  Released                nb  103.000000     4159678        1
# 22  Released                nl  107.333333     5475058        6
# 23  Released                no   95.500000     1984662        2
# 24  Released                pl   99.000000    15298355        2
# 25  Released                pt  114.666667    56702901        6
# 26  Released                ro  108.750000     1185783        4
# 27  Released                ru   95.586957    55635037       47
# 28  Released                sr   97.000000         198        1
# 29  Released                sv  122.375000    66995253        8
# 30  Released                ta  159.875000    62000000       16
# 31  Released                te  146.000000    14000000        2
# 32  Released                tr  119.000000   149521495        3
# 33  Released                ur   94.000000      645135        1
# 34  Released                vi  135.000000      639000        1
# 35  Released                zh  121.368421   385284817       19
# 36   Rumored                en   77.250000    13418091        4

# %% [markdown]
# ### Joining Dataframes

# %%
# .merge(), .concat()
# Inner join, left join, right join, outer join
# pd.concat( [df] , axis)

# pd.merge(df1, df2 ,on,how)

# %% [markdown]
# #### .concat()

# %%
# read_imdb_data.original_language.value_counts()

# %%
read_imdb_data_en = read_imdb_data.loc[read_imdb_data.original_language == 'en',]
read_imdb_data_other = read_imdb_data.loc[read_imdb_data.original_language != 'en',]

# %%
read_imdb_data_en.shape
# Out:
# (2575, 24)

# %%
read_imdb_data_other.shape
# Out:
# (425, 24)

# %%
df_final = pd.concat([read_imdb_data_en,read_imdb_data_other],axis = 0)

# %%
df_final.shape
# Out:
# (3000, 24)

# %%
data1 = {'ID': [1, 2, 3],
         'Name': ['John', 'Alice', 'Bob'],
         'Age': [30, 25, 35]}
df1 = pd.DataFrame(data1)
df1
# Out:
#    ID   Name  Age
# 0   1   John   30
# 1   2  Alice   25
# 2   3    Bob   35

# %%
data2 = {'Salary': [50000, 60000, 70000]}
df2 = pd.DataFrame(data2)
df2
# Out:
#    Salary
# 0   50000
# 1   60000
# 2   70000

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    ID   Name  Age  Salary
# 0   1   John   30   50000
# 1   2  Alice   25   60000
# 2   3    Bob   35   70000

# %% [markdown]
# #### .merge()

# %%
data1 = {'ID': [1, 2, 3, 4],
         'Name': ['John', 'Alice', 'Bob', 'Charlie'],
         'Age': [30, 25, 35, 40]}
df1 = pd.DataFrame(data1)
data2 = {'salary_ID': [2, 3, 5, 6],
         'Salary': [50000, 60000, 70000, 80000]}
df2 = pd.DataFrame(data2)
print(df1)
print(df2)
# Out:
#    ID     Name  Age
# 0   1     John   30
# 1   2    Alice   25
# 2   3      Bob   35
# 3   4  Charlie   40
#    salary_ID  Salary
# 0          2   50000
# 1          3   60000
# 2          5   70000
# 3          6   80000

# %%
# Inner
pd.merge(df1,df2, left_on = 'ID', right_on = 'salary_ID', how ='inner')
# Out:
#    ID   Name  Age  salary_ID  Salary
# 0   2  Alice   25          2   50000
# 1   3    Bob   35          3   60000

# %%
# left
pd.merge(df1,df2, left_on = 'ID', right_on = 'salary_ID', how ='left')
# Out:
#    ID     Name  Age  salary_ID   Salary
# 0   1     John   30        NaN      NaN
# 1   2    Alice   25        2.0  50000.0
# 2   3      Bob   35        3.0  60000.0
# 3   4  Charlie   40        NaN      NaN

# %%
# right
pd.merge(df1,df2, left_on = 'ID', right_on = 'salary_ID', how ='right')
# Out:
#     ID   Name   Age  salary_ID  Salary
# 0  2.0  Alice  25.0          2   50000
# 1  3.0    Bob  35.0          3   60000
# 2  NaN    NaN   NaN          5   70000
# 3  NaN    NaN   NaN          6   80000

# %%
# outer
pd.merge(df1,df2, left_on = 'ID', right_on = 'salary_ID', how ='outer')
# Out:
#     ID     Name   Age  salary_ID   Salary
# 0  1.0     John  30.0        NaN      NaN
# 1  2.0    Alice  25.0        2.0  50000.0
# 2  3.0      Bob  35.0        3.0  60000.0
# 3  4.0  Charlie  40.0        NaN      NaN
# 4  NaN      NaN   NaN        5.0  70000.0
# 5  NaN      NaN   NaN        6.0  80000.0

# %%
# Cross join :: Try to search for it.
# Key
df1['key'] = 1
df2['key'] = 1
pd.merge(df1,df2, on = 'key', how = 'outer')
# Out:
#     ID     Name  Age  key  salary_ID  Salary
# 0    1     John   30    1          2   50000
# 1    1     John   30    1          3   60000
# 2    1     John   30    1          5   70000
# 3    1     John   30    1          6   80000
# 4    2    Alice   25    1          2   50000
# 5    2    Alice   25    1          3   60000
# 6    2    Alice   25    1          5   70000
# 7    2    Alice   25    1          6   80000
# 8    3      Bob   35    1          2   50000
# 9    3      Bob   35    1          3   60000
# 10   3      Bob   35    1          5   70000
# 11   3      Bob   35    1          6   80000
# 12   4  Charlie   40    1          2   50000
# 13   4  Charlie   40    1          3   60000
# 14   4  Charlie   40    1          5   70000
# 15   4  Charlie   40    1          6   80000

# %% [markdown]
# ### .replace(),.apply()

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.original_language.value_counts().reset_index()
# Out:
#    original_language  count
# 0                 en   2575
# 1                 fr     78
# 2                 ru     47
# 3                 es     43
# 4                 hi     42
# 5                 ja     37
# 6                 it     24
# 7                 cn     20
# 8                 ko     20
# 9                 zh     19
# 10                de     18
# 11                ta     16
# 12                sv      8
# 13                nl      6
# 14                pt      6
# 15                fa      5
# 16                da      5
# 17                ro      4
# 18                hu      3
# 19                tr      3
# 20                no      2
# 21                ml      2
# 22                pl      2
# 23                te      2
# 24                fi      2
# 25                ur      1
# 26                he      1
# 27                el      1
# 28                ar      1
# 29                nb      1
# 30                vi      1
# 31                mr      1
# 32                cs      1
# 33                sr      1
# 34                bn      1
# 35                id      1

# %%
read_imdb_data.original_language.replace({'en':'english','hi':'hindi'})
# Out:
# 0       english
# 1       english
# 2       english
# 3         hindi
# 4            ko
#          ...
# 2995    english
# 2996         sv
# 2997    english
# 2998    english
# 2999    english
# Name: original_language, Length: 3000, dtype: object

# %%
### how do we replace rest to others? --> We use apply with custom function

# %% [markdown]
# #### .apply()

# %%
read_imdb_data.original_language
# Out:
# 0       en
# 1       en
# 2       en
# 3       hi
# 4       ko
#         ..
# 2995    en
# 2996    sv
# 2997    en
# 2998    en
# 2999    en
# Name: original_language, Length: 3000, dtype: object

# %%
def lang_map(l): # custom function
  if l == 'en':
    return 'english'
  elif l == 'hi':
    return 'hindi'
  else:
    return 'others'

lang_map(l = 'en')
# Out:
# 'english'

# %%
read_imdb_data.original_language = read_imdb_data.original_language.apply(lang_map) # Applied to each element

# %%
def first_letter(s):
  return s[0]

# %%
read_imdb_data.original_language.apply(first_letter)
# Out:
# 0       e
# 1       e
# 2       e
# 3       h
# 4       k
#        ..
# 2995    e
# 2996    s
# 2997    e
# 2998    e
# 2999    e
# Name: original_language, Length: 3000, dtype: object

# %%
def lang_chang(l):
  if l == 'en':
    return 'english'
  elif l == 'hi':
    return 'hindi'
  else:
    return l

# %%
read_imdb_data.original_language.apply(lang_chang)
# Out:
# 0       english
# 1       english
# 2       english
# 3         hindi
# 4            ko
#          ...
# 2995    english
# 2996         sv
# 2997    english
# 2998    english
# 2999    english
# Name: original_language, Length: 3000, dtype: object

# %% [markdown]
# ### Dealing with Strings, Datetime & Json data in column

# %% [markdown]
# ##### Strings

# %%
# Important functions
# str.contains(), str.find(''),str.replace(old,new), str.split('delimiter'), str.strip(), str.extract() and str.extractall()

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# str.contains()
# read_imdb_data.title.str.contains('Time') # Exact match as substring
# read_imdb_data.title.str.contains(r'[0-9]{1,}') # Match as regex

# %%
# .loc[row_name,column_name]
# .iloc[row_index,column_index]

# %%
# read_imdb_data.loc[read_imdb_data.title.str.contains('Time'),]

# %%
read_imdb_data.title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# str.find('')
# read_imdb_data.title.str.find('h') # -1 if not found , otherwise first occurance.
# Out:
# 0       16
# 1        1
# 2        1
# 3        2
# 4       -1
#         ..
# 2995     1
# 2996     8
# 2997     1
# 2998    -1
# 2999    -1
# Name: title, Length: 3000, dtype: int64

# %%
# str.replace(old,new)
# read_imdb_data.title.str.replace('Time','TIME') # Replace Exact match as substring
# read_imdb_data.title.str.replace(r'[0-9]{1,}','&', regex=True) # Match as regex
# Out:
# 0                         Hot Tub Time Machine &
# 1       The Princess Diaries &: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
read_imdb_data.title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
def get_3_value(x):
  if len(x) < 3:
    return x
  else:
    return x[2]

# %%
read_imdb_data.title.str.split(' ')

# %%
# str.split('delimiter')
read_imdb_data.title.str.split(' ').apply(get_3_value) # Splits the string and converts it to list
# Out:
# 0                Time
# 1             Diaries
# 2          [Whiplash]
# 3           [Kahaani]
# 4       [Marine, Boy]
#             ...
# 2995        [Chasers]
# 2996              the
# 2997             Kiss
# 2998            Polly
# 2999      [Abduction]
# Name: title, Length: 3000, dtype: object

# %%
df = pd.read_csv()
# df.drop_duplicates()
# run .strip for each categorical column

# %%
# str.strip() --> Strips the extra space
read_imdb_data.title.str.strip()
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# My email id is alok@febfwjf.com
# ravi@jefrjnfre;f.com is my email id.

# %%
read_imdb_data.title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# str.contains('Time') and str.contains('Machine')

# %%
read_imdb_data.title.str.contains(r'([0-9]{1,})')
# Out:
# <ipython-input-72-5667d63e85b8>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   read_imdb_data.title.str.contains(r'([0-9]{1,})')
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: title, Length: 3000, dtype: bool

# %%
df1 = read_imdb_data.title.str.extract(r'([0-9]{1,})').reset_index()
df1.loc[df1.index ==2960,]
# Out:
#       index  0
# 2960   2960  4

# %%
read_imdb_data.loc[21,]
# Out:
# id                                                                      22
# belongs_to_collection    [{'id': 9735, 'name': 'Friday the 13th Collect...
# budget                                                             4000000
# genres                   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# homepage                                                               NaN
# imdb_id                                                          tt0083972
# original_language                                                       en
# original_title                                    Friday the 13th Part III
# overview                 An idyllic summer turns into a nightmare of un...
# popularity                                                         7.99229
# poster_path                               /5wg2NZyIhcMbIBAahBODXHyJ54S.jpg
# production_companies     [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                       8/13/82
# runtime                                                               95.0
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                            Released
# tagline                       There's nowhere to hide. We dare you to try.
# title                                             Friday the 13th Part III
# Keywords                 [{'id': 1889, 'name': 'lake'}, {'id': 5767, 'n...
# cast                     [{'cast_id': 1, 'character': 'Chris Higgins', ...
# crew                     [{'credit_id': '52fe4523c3a36847f80be885', 'de...
# revenue                                                           36690067
# Name: 21, dtype: object

# %%
data = [{'name':'John', 'about':'My contact detail is 9876543210, Call me for the house repair'},
        {'name':'Albert','about':'4567890123 is my contact detail, you can contact me for the problem with electricty, my alternate number is 6789012343'}]

df = pd.DataFrame(data)
df
# Out:
#      name                                              about
# 0    John  My contact detail is 9876543210, Call me for t...
# 1  Albert  4567890123 is my contact detail, you can conta...

# %%
df.about.str.extract(r'([0-9]{10})')
# Out:
#             0
# 0  9876543210
# 1  4567890123

# %%
df.about.str.extractall(r'([0-9]{10})')
# Out:
#                   0
#   match
# 0 0      9876543210
# 1 0      4567890123
#   1      6789012343

# %%
# str.extract() and str.extractall() --> Extracts the substring based on regex pattern
# read_imdb_data.title.str.extract(r'([0-9]{1,})') # Extracts first match
read_imdb_data.title.str.extractall(r'([0-9]{1,})').reset_index() # Extracts all matches
# Out:
#      level_0  match   0
# 0          0      0   2
# 1          1      0   2
# 2         19      0   2
# 3         21      0  13
# 4         33      0   2
# ..       ...    ...  ..
# 202     2958      1   3
# 203     2960      0   4
# 204     2960      1   3
# 205     2960      2   2
# 206     2960      3   1
#
# [207 rows x 3 columns]

# %%
read_imdb_data.loc[2960,'title']
# Out:
# '4.3.2.1'

# %% [markdown]
# ##### Datetime

# %%
# Converting String to Datetime
# Extracting components from the datetime
# Create a timedelta object representing a duration : Adding or substracting some year,months, days, hours,minutes,etc
# Subtracting two datetime
# Putting filter on datetime

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294           english
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
read_imdb_data['release_date'].head(5)
# Out:
# 0     2/20/15
# 1      8/6/04
# 2    10/10/14
# 3      3/9/12
# 4      2/5/09
# Name: release_date, dtype: object

# %%
data = [{'index':0,'date':'01-09-24'},{'index':1,'date':'01-11-22'}]
df = pd.DataFrame(data)
df
# Out:
#    index      date
# 0      0  01-09-24
# 1      1  01-11-22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   2 non-null      int64
#  1   date    2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
df.date = pd.to_datetime(df.date,format= '%d-%m-%y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   2 non-null      int64
#  1   date    2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 160.0 bytes

# %%
# Converting String to Datetime
# .to_datetime
# Ref : https://www.geeksforgeeks.org/python-datetime-strptime-function/

read_imdb_data.release_date = pd.to_datetime(read_imdb_data.release_date,format= '%m/%d/%y')

# %%
read_imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(17)
# memory usage: 539.2+ KB

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...   2015-02-20    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.release_date
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
# Extracting components from the datetime
# dt. --> day,date, year, month,week, hour, day_name(), dayofyear,weekday(Monday=0, Sunday=6)
read_imdb_data['release_day'] = read_imdb_data.release_date.dt.day_name()

# %%
read_imdb_data['release_day'].head()
# Out:
# 0      Friday
# 1      Friday
# 2      Friday
# 3      Friday
# 4    Thursday
# Name: release_day, dtype: object

# %%
read_imdb_data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'release_day'],
#       dtype='object')

# %%
# read_imdb_data.loc[:,['belongs_to_collection','id',  'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'release_day']]

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... runtime                          spoken_languages  \
# 0    6.575393  ...    93.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
#
#                     title                                           Keywords  \
# 0  Hot Tub Time Machine 2  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue release_day
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651      Friday
#
# [1 rows x 24 columns]

# %%
read_imdb_data.release_date.head(1)
# Out:
# 0   2015-02-20
# Name: release_date, dtype: datetime64[ns]

# %%
read_imdb_data.release_date
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
# Create a timedelta object representing a duration : Adding or substracting some [weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds]
# pd.Timedelta(days=2)
read_imdb_data.release_date - pd.Timedelta(weeks = 1)
# Out:
# 0      2015-02-13
# 1      2004-07-30
# 2      2014-10-03
# 3      2012-03-02
# 4      2009-01-29
#           ...
# 2995   1994-04-15
# 2996   2013-03-21
# 2997   1996-10-04
# 2998   2004-01-09
# 2999   2011-09-15
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
read_imdb_data.loc[:,'release_date_plus2d'] = read_imdb_data.release_date + pd.Timedelta(days = 2)

# %%
(read_imdb_data.release_date_plus2d - read_imdb_data.release_date).dt.days
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 2995    2
# 2996    2
# 2997    2
# 2998    2
# 2999    2
# Length: 3000, dtype: int64

# %%
# Subtracting two datetime
read_imdb_data.loc[:,'date_diff'] = (read_imdb_data.release_date_plus2d - read_imdb_data.release_date).dt.days

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                          spoken_languages    status  \
# 0    6.575393  ...  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
#   release_date_plus2d date_diff
# 0          2015-02-22         2
#
# [1 rows x 25 columns]

# %%
# Putting filter on datetime
read_imdb_data.loc[read_imdb_data.release_date > '2019-01-01',].sort_values(by='release_date', ascending = True)
# Out:
#         id                              belongs_to_collection    budget  \
# 1763  1764                                                NaN    250000
# 2992  2993                                                NaN   1135654
# 1917  1918                                                NaN       592
# 1361  1362                                                NaN         0
# 2680  2681                                                NaN    463455
# ...    ...                                                ...       ...
# 1034  1035                                                NaN         0
# 2147  2148  [{'id': 264338, 'name': "Rosemary's Baby Colle...   3200000
# 140    141                                                NaN  14320000
# 647    648                                                NaN   9000000
# 2649  2650                                                NaN   1455000
#
#                                                  genres homepage    imdb_id  \
# 1763  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0012349
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN  tt0015400
# 1917  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN  tt0016104
# 1361  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN  tt0015648
# 2680                      [{'id': 18, 'name': 'Drama'}]      NaN  tt0017423
# ...                                                 ...      ...        ...
# 1034  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  tt0063518
# 2147  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...      NaN  tt0063522
# 140   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN  tt0063642
# 647            [{'id': 878, 'name': 'Science Fiction'}]      NaN  tt0062711
# 2649                    [{'id': 37, 'name': 'Western'}]      NaN  tt0063592
#
#      original_language         original_title  \
# 1763                en                The Kid
# 2992                en    The Thief of Bagdad
# 1917                en        The Merry Widow
# 1361                ru  Броненосец «Потёмкин»
# 2680                en               Sparrows
# ...                ...                    ...
# 1034                en       Romeo and Juliet
# 2147                en        Rosemary's Baby
# 140                 en                  Star!
# 647                 en             Barbarella
# 2649                en                Shalako
#
#                                                overview  popularity  ...  \
# 1763  Considered one of Charlie Chaplin's best films...    8.168456  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 1917  Prince Danilo falls in love with dancer Sally ...    0.286719  ...
# 1361  A dramatized account of a great Russian naval ...   12.912845  ...
# 2680  Evil Mr.Grimes keeps a rag-tag bunch orphans o...    0.445526  ...
# ...                                                 ...         ...  ...
# 1034  Director Franco Zeffirelli's beloved version o...    6.990990  ...
# 2147  A young couple moves into an infamous New York...   11.504558  ...
# 140   Gertrude Lawrence rises to stage stardom at th...    0.585397  ...
# 647   In the far future, a highly sexual woman is ta...   14.304205  ...
# 2649  Sean Connery is Shalako, a guide in the old We...    6.229674  ...
#
#                                        spoken_languages    status  \
# 1763       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 1917                                                NaN  Released
# 1361           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 2680           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                 ...       ...
# 1034  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2147           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 140            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 647            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2649  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
#
#                                                 tagline                title  \
# 1763                                    6 reels of Joy.              The Kid
# 2992                         "Happiness Must Be Earned"  The Thief of Bagdad
# 1917                                                NaN      The Merry Widow
# 1361  Revolution is the only lawful, equal, effectua...  Battleship Potemkin
# 2680                                                NaN             Sparrows
# ...                                                 ...                  ...
# 1034                          No ordinary love story...     Romeo and Juliet
# 2147                           Pray for Rosemary's Baby      Rosemary's Baby
# 140                   Happiness is a girl called Julie!                Star!
# 647                        See Barbarella do her thing!           Barbarella
# 2649  Sean Connery is Shalako! Shalako means action!...              Shalako
#
#                                                Keywords  \
# 1763  [{'id': 290, 'name': 'angel'}, {'id': 1252, 'n...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 1917  [{'id': 1691, 'name': 'dance'}, {'id': 10181, ...
# 1361  [{'id': 1816, 'name': 'staircase'}, {'id': 323...
# 2680  [{'id': 1930, 'name': 'kidnapping'}, {'id': 49...
# ...                                                 ...
# 1034  [{'id': 255, 'name': 'male nudity'}, {'id': 16...
# 2147  [{'id': 8685, 'name': 'anti-christ'}, {'id': 1...
# 140   [{'id': 4344, 'name': 'musical'}, {'id': 12990...
# 647   [{'id': 9835, 'name': 'sexual fantasy'}, {'id'...
# 2649  [{'id': 10322, 'name': 'native american'}, {'i...
#
#                                                    cast  \
# 1763  [{'cast_id': 10, 'character': 'A Tramp', 'cred...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 1917  [{'cast_id': 2, 'character': "Sally O'Hara", '...
# 1361  [{'cast_id': 8, 'character': 'Grigory Vakulinc...
# 2680  [{'cast_id': 2, 'character': 'Molly', 'credit_...
# ...                                                 ...
# 1034  [{'cast_id': 6, 'character': 'Romeo', 'credit_...
# 2147  [{'cast_id': 15, 'character': 'Rosemary Woodho...
# 140   [{'cast_id': 3, 'character': 'Gertrude Lawrenc...
# 647   [{'cast_id': 2, 'character': 'Barbarella', 'cr...
# 2649  [{'cast_id': 3, 'character': "Moses Zebulon 'S...
#
#                                                    crew   revenue release_day  \
# 1763  [{'credit_id': '52fe43269251416c75005605', 'de...   2500000    Thursday
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...   1213880      Monday
# 1917  [{'credit_id': '57351170c3a36802410000d5', 'de...         1     Tuesday
# 1361  [{'credit_id': '52fe4263c3a36847f801a8cf', 'de...     45100   Wednesday
# 2680  [{'credit_id': '52fe48a1c3a368484e102bd9', 'de...    966878    Thursday
# ...                                                 ...       ...         ...
# 1034  [{'credit_id': '52fe4435c3a36847f80889c3', 'de...  38901218      Monday
# 2147  [{'credit_id': '52fe4279c3a36847f8021573', 'de...  33395426     Tuesday
# 140   [{'credit_id': '52fe484bc3a36847f81602c9', 'de...  14000000   Wednesday
# 647   [{'credit_id': '52fe4491c3a36847f809d5ab', 'de...   2500000   Wednesday
# 2649  [{'credit_id': '52fe47029251416c9106740b', 'de...   2620000     Tuesday
#
#      release_date_plus2d
# 1763          2021-01-23
# 2992          2024-03-20
# 1917          2025-08-28
# 1361          2025-12-26
# 2680          2026-05-16
# ...                  ...
# 1034          2068-04-04
# 2147          2068-06-14
# 140           2068-07-20
# 647           2068-10-12
# 2649          2068-11-08
#
# [146 rows x 25 columns]

# %% [markdown]
# ##### Dealing with JSON

# %%
# pd.json_normalize()

# %%
pd.json_normalize([{'a':1,'b':4},{'a':9,'b':7}])
# Out:
#    a  b
# 0  1  4
# 1  9  7

# %%
# pd.DataFrame([{'a':1,'b':4},{'a':9,'b':7}])
# Out:
#    a  b
# 0  1  4
# 1  9  7

# %%
pd.json_normalize([{'a':1,'b':{'c':2,'d':3}},{'a':9,'b':{'c':10,'d':11,'e':12}}])
# Out:
#    a  b.c  b.d   b.e
# 0  1    2    3   NaN
# 1  9   10   11  12.0

# %%
# pd.json_normalize([{'a':1,'b':{'c':2,'d':3}},{'a':9,'b':{'c':10,'d':11,'e':12}}])

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                          spoken_languages    status  \
# 0    6.575393  ...  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
#   release_date_plus2d date_diff
# 0          2015-02-22         2
#
# [1 rows x 25 columns]

# %%
read_imdb_data.genres[0]
# Out:
# "[{'id': 35, 'name': 'Comedy'}]"

# %%
pd.json_normalize(eval(read_imdb_data.genres[0]))
# Out:
#    id    name
# 0  35  Comedy

# %%
# Steps to take :
# 1. First implement eval to convert from str to Json (list of dict)
# 2. pd.json_normalize to make it dataframe
# 3. get the name column as series, convert to list and join comma separated

# %%
read_imdb_data.genres[0]
# Out:
# "[{'id': 35, 'name': 'Comedy'}]"

# %%
# extract Genre for the movies
# Custom function
def parse_json(s,key):
  try:
    j = eval(s) # list of dictionaries
    return ','.join(list(pd.json_normalize(j)[key]))
  except:
    return s

# %%
read_imdb_data.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
#
# [2 rows x 23 columns]

# %%
# list(read_imdb_data.genres[1])

# %%
j = eval(read_imdb_data.genres[1])

# %%
pd.json_normalize(j)
# Out:
#       id     name
# 0     35   Comedy
# 1     18    Drama
# 2  10751   Family
# 3  10749  Romance

# %%
list(pd.json_normalize(j)['name'])
# Out:
# ['Comedy', 'Drama', 'Family', 'Romance']

# %%
# Comedy,Drama,Family,Romance
','.join(list(pd.json_normalize(j)['name']))
# Out:
# 'Comedy,Drama,Family,Romance'

# %%
# ','.join(list(pd.json_normalize(j)['name']))
# Out:
# 'Comedy,Drama,Family,Romance'

# %%
# ','.join(list(pd.json_normalize(j)[key]))

# %%
# parse_json(s = read_imdb_data.genres[0],key = 'name')
# Out:
# 'Comedy'

# %%
read_imdb_data.genres.apply(parse_json,key = 'name')
# Out:
# 0                              Comedy
# 1         Comedy,Drama,Family,Romance
# 2                               Drama
# 3                      Thriller,Drama
# 4                     Action,Thriller
#                     ...
# 2995                   Comedy,Romance
# 2996                      Drama,Music
# 2997    Crime,Action,Mystery,Thriller
# 2998                   Comedy,Romance
# 2999          Thriller,Action,Mystery
# Name: genres, Length: 3000, dtype: object

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.spoken_languages.head(10)
# Out:
# 0             [{'iso_639_1': 'en', 'name': 'English'}]
# 1             [{'iso_639_1': 'en', 'name': 'English'}]
# 2             [{'iso_639_1': 'en', 'name': 'English'}]
# 3    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4             [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5             [{'iso_639_1': 'en', 'name': 'English'}]
# 6             [{'iso_639_1': 'en', 'name': 'English'}]
# 7    [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8             [{'iso_639_1': 'en', 'name': 'English'}]
# 9             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, dtype: object

# %%
read_imdb_data.spoken_languages.apply(parse_json,key = 'iso_639_1')
# Out:
# 0          en
# 1          en
# 2          en
# 3       en,hi
# 4          ko
#         ...
# 2995       en
# 2996       sv
# 2997       en
# 2998       en
# 2999       en
# Name: spoken_languages, Length: 3000, dtype: object

# %%
# read_imdb_data.cast.apply(parse_json,key = 'name')
# Out:
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 3000, dtype: object

# %% [markdown]
# ### Reshaping data

# %%
# .pivot(), .crosstab(), .astype()

# %%
read_imdb_data.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
read_imdb_data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
read_imdb_data.groupby(['original_language','release_date']).agg({'runtime':'mean','revenue':'mean'}).reset_index().sort_values('original_language')
# Out:
#      original_language release_date  runtime     revenue
# 0              english   1969-01-01    149.0  20000000.0
# 1422           english   2010-04-23    101.5  38750433.5
# 1421           english   2010-04-02     92.0  39340177.0
# 1420           english   2010-04-01    118.0   3878993.0
# 1419           english   2010-03-22    117.0  96188903.0
# ...                ...          ...      ...         ...
# 2278            others   2005-05-02    117.0  36000000.0
# 2277            others   2005-03-05    126.0   8262833.0
# 2276            others   2004-12-23     72.0   1730000.0
# 2285            others   2005-08-04    133.0  33579813.0
# 2528            others   2068-03-22    107.0     44566.0
#
# [2529 rows x 4 columns]

# %%
# df.pivot(index='col1', columns='col2', values=['col']) # note: index & column must be unique
# Function used in combination with group by

# %%
read_imdb_data.groupby(['original_language','release_date']).agg({'revenue':'mean'}).reset_index()
# Out:
#      original_language release_date      revenue
# 0              english   1969-01-01   20000000.0
# 1              english   1969-06-17     638641.0
# 2              english   1969-09-23  102308889.0
# 3              english   1969-12-12   33208099.0
# 4              english   1969-12-18    6000000.0
# ...                ...          ...          ...
# 2524            others   2060-05-24    8000000.0
# 2525            others   2064-08-05     182857.0
# 2526            others   2066-04-05      17277.0
# 2527            others   2066-09-08     921548.0
# 2528            others   2068-03-22      44566.0
#
# [2529 rows x 3 columns]

# %%
read_imdb_data_grpd_pivot
# Out:
#                   release_date      revenue
# original_language                   english hindi    others
# 0                   1969-01-01   20000000.0   NaN       NaN
# 1                   1969-06-17     638641.0   NaN       NaN
# 2                   1969-09-10          NaN   NaN  741766.0
# 3                   1969-09-23  102308889.0   NaN       NaN
# 4                   1969-12-12   33208099.0   NaN       NaN
# ...                        ...          ...   ...       ...
# 2393                2068-04-02   38901218.0   NaN       NaN
# 2394                2068-06-12   33395426.0   NaN       NaN
# 2395                2068-07-18   14000000.0   NaN       NaN
# 2396                2068-10-10    2500000.0   NaN       NaN
# 2397                2068-11-06    2620000.0   NaN       NaN
#
# [2398 rows x 4 columns]

# %%
read_imdb_data.groupby(['original_language','release_date']).agg({'revenue':'mean'})
# Out:
#                                     revenue
# original_language release_date
# english           1969-01-01     20000000.0
#                   1969-06-17       638641.0
#                   1969-09-23    102308889.0
#                   1969-12-12     33208099.0
#                   1969-12-18      6000000.0
# ...                                     ...
# others            2060-05-24      8000000.0
#                   2064-08-05       182857.0
#                   2066-04-05        17277.0
#                   2066-09-08       921548.0
#                   2068-03-22        44566.0
#
# [2529 rows x 1 columns]

# %%
read_imdb_data_grpd = read_imdb_data.groupby(['original_language','release_date']).agg({'revenue':'mean'}).reset_index()

# %%
read_imdb_data_grpd_pivot = read_imdb_data_grpd.pivot(index = 'release_date',columns = 'original_language', values = [	'revenue']).reset_index()

# %%
read_imdb_data_grpd_pivot
# Out:
#                   release_date      revenue
# original_language                   english hindi    others
# 0                   1969-01-01   20000000.0   NaN       NaN
# 1                   1969-06-17     638641.0   NaN       NaN
# 2                   1969-09-10          NaN   NaN  741766.0
# 3                   1969-09-23  102308889.0   NaN       NaN
# 4                   1969-12-12   33208099.0   NaN       NaN
# ...                        ...          ...   ...       ...
# 2393                2068-04-02   38901218.0   NaN       NaN
# 2394                2068-06-12   33395426.0   NaN       NaN
# 2395                2068-07-18   14000000.0   NaN       NaN
# 2396                2068-10-10    2500000.0   NaN       NaN
# 2397                2068-11-06    2620000.0   NaN       NaN
#
# [2398 rows x 4 columns]

# %%
read_imdb_data_grpd_pivot.columns
# Out:
# MultiIndex([('release_date',        ''),
#             (     'runtime', 'english'),
#             (     'runtime',   'hindi'),
#             (     'runtime',  'others'),
#             (     'revenue', 'english'),
#             (     'revenue',   'hindi'),
#             (     'revenue',  'others')],
#            names=[None, 'original_language'])

# %%
read_imdb_data_grpd_pivot.head()
# Out:
#                   release_date runtime                   revenue        \
# original_language              english hindi others      english hindi
# 0                   1969-01-01   149.0   NaN    NaN   20000000.0   NaN
# 1                   1969-06-17   145.0   NaN    NaN     638641.0   NaN
# 2                   1969-09-10     NaN   NaN  145.0          NaN   NaN
# 3                   1969-09-23   110.0   NaN    NaN  102308889.0   NaN
# 4                   1969-12-12   146.0   NaN    NaN   33208099.0   NaN
#
#
# original_language    others
# 0                       NaN
# 1                       NaN
# 2                  741766.0
# 3                       NaN
# 4                       NaN

# %%
read_imdb_data_grpd_pivot.loc[:30,[('runtime', 'others'),('revenue','hindi')]]
# Out:
#                   runtime revenue
# original_language  others   hindi
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                   145.0     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
# 5                     NaN     NaN
# 6                     NaN     NaN
# 7                     NaN     NaN
# 8                     NaN     NaN
# 9                   126.0     NaN
# 10                    NaN     NaN
# 11                    NaN     NaN
# 12                    NaN     NaN
# 13                    NaN     NaN
# 14                    NaN     NaN
# 15                    NaN     NaN
# 16                    NaN     NaN
# 17                    NaN     NaN
# 18                    NaN     NaN
# 19                    NaN     NaN
# 20                    NaN     NaN
# 21                    NaN     NaN
# 22                    NaN     NaN
# 23                  101.0     NaN
# 24                    NaN     NaN
# 25                    NaN     NaN
# 26                    NaN     NaN
# 27                    NaN     NaN
# 28                   98.0     NaN
# 29                  129.0     NaN
# 30                  115.0     NaN

# %%
# Accuracy --> Actual vs Predicted
# heatmap --> For categorical vs categorical Variable

# %%
read_imdb_data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294           english
# 1                                NaN  tt0368933           english
# 2  http://sonyclassics.com/whiplash/  tt2582802           english
# 3         http://kahaanithefilm.com/  tt1821480             hindi
# 4                                NaN  tt1380152            others
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0   2015-02-20    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1   2004-08-06   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2   2014-10-10   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   2012-03-09   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4   2009-02-05   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
read_imdb_data.groupby(['release_date','original_language'])['id'].count().reset_index()
# Out:
#      release_date original_language  id
# 0      1969-01-01           english   1
# 1      1969-06-17           english   1
# 2      1969-09-10            others   1
# 3      1969-09-23           english   1
# 4      1969-12-12           english   1
# ...           ...               ...  ..
# 2524   2068-04-02           english   1
# 2525   2068-06-12           english   1
# 2526   2068-07-18           english   1
# 2527   2068-10-10           english   1
# 2528   2068-11-06           english   1
#
# [2529 rows x 3 columns]

# %%
# .crosstab() -->
pd.crosstab(read_imdb_data.release_date,read_imdb_data.original_language ).reset_index()
# Out:
# original_language release_date  english  hindi  others
# 0                   1969-01-01        1      0       0
# 1                   1969-06-17        1      0       0
# 2                   1969-09-10        0      0       1
# 3                   1969-09-23        1      0       0
# 4                   1969-12-12        1      0       0
# ...                        ...      ...    ...     ...
# 2393                2068-04-02        1      0       0
# 2394                2068-06-12        1      0       0
# 2395                2068-07-18        1      0       0
# 2396                2068-10-10        1      0       0
# 2397                2068-11-06        1      0       0
#
# [2398 rows x 4 columns]

# %%
read_imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(17)
# memory usage: 539.2+ KB

# %%
# .astype() --> Typecasting
# Int to str
read_imdb_data.id.astype('str').astype('int')
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2995    2996
# 2996    2997
# 2997    2998
# 2998    2999
# 2999    3000
# Name: id, Length: 3000, dtype: int64

# %%
read_imdb_data['date_concat'] = read_imdb_data.release_date.dt.year.astype('str') + '-' + read_imdb_data.release_date.dt.month.astype('str')

# %%
read_imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
#  23  date_concat            3000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(18)
# memory usage: 562.6+ KB

# %%
read_imdb_data.date_concat[0]
# Out:
# '2015-2'

# %% [markdown]
# ### Caching & Parallelization

# %%
#  Parallelization & Caching

# %% [markdown]
# #####  Parallelization

# %%
# Parallelization
# !pip install pandarallel
from pandarallel import pandarallel
# Out:
# Collecting pandarallel
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dill>=0.3.1 (from pandarallel)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from pandarallel) (2.0.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pandarallel) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->pandarallel) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1->pandarallel) (1.16.0)
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16673 sha256=965f1d064002ecfea78fb7d4139444b5d6d4681187e0e5121098f4340fc1be89
#   Stored in directory: /root/.cache/pip/wheels/50/4f/1e/34e057bb868842209f1623f195b74fd7eda229308a7352d47f
# Successfully built pandarallel
# Installing collected packages: dill, pandarallel
# Successfully installed dill-0.3.8 pandarallel-1.6.5

# %%
# pandarallel.initialize(nb_workers=1)

# %%
# %time  --> 1 execution and time taken
# %timeit --> 1000 executions and avg time taken

# %%
read_imdb_data = pd.concat([read_imdb_data]* 5)
read_imdb_data.shape
# Out:
# (15000, 23)

# %%
# Column with all links.parallel_apply(funciton)

# %%
pandarallel.initialize(nb_workers=1)
# %time read_imdb_data.cast.parallel_apply(parse_json,key = 'name')
# Out:
# INFO: Pandarallel will run on 1 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# CPU times: user 527 ms, sys: 139 ms, total: 666 ms
# Wall time: 1min 36s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 15000, dtype: object

# %%
pandarallel.initialize(nb_workers = 2)
# %time read_imdb_data.cast.parallel_apply(parse_json,key = 'name')
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# CPU times: user 316 ms, sys: 138 ms, total: 455 ms
# Wall time: 57.6 s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 15000, dtype: object

# %%
# pandarallel.initialize(nb_workers = 4)
# %time read_imdb_data.cast.parallel_apply(parse_json,key = 'name')
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# CPU times: user 60.6 ms, sys: 80.1 ms, total: 141 ms
# Wall time: 5.86 s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 3000, dtype: object

# %%
# %time read_imdb_data.cast.apply(parse_json,key = 'name')
# Out:
# CPU times: user 45.8 s, sys: 304 ms, total: 46.1 s
# Wall time: 46.5 s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 30000, dtype: object

# %% [markdown]
# ##### Caching

# %%
# joblib
from joblib import Memory
mem = Memory(location='cache')

# %%
@mem.cache
def parse_json_cache(s,key):
  try:
    j= eval(s)
    return ','.join(list(pd.json_normalize(j)[key]))
  except:
    return s

# %%
# %time read_imdb_data.cast.apply(parse_json_cache,key = 'name') #First time run
# Out:
# Streaming output truncated to the last 5000 lines.
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 11, 'character': 'Caesar', 'credit_id': "
#  "'52fe430ec3a36847f8037199', 'gender': 2, 'id': 7505, 'name': 'Roddy "
#  "McDowall', 'order': 0, 'profile_path': '/e0OZn5SUXHghdmAgJbF3uLHD5gf.jpg'}, "
#  "{'cast_id': 21, 'character': 'Lisa', 'credit_id': "
#  "'52fe430ec3a36847f80371bf', 'gender': 1, 'id': 18648, 'name': 'Natalie "
#  "Trundy', 'order': 1, 'profile_path': '/50ljrtCFeFQRFURoSgf1hrgdCPw.jpg'}, "
#  "{'cast_id': 23, 'character': 'MacDonald', 'credit_id': "
#  "'52fe430ec3a36847f80371c7', 'gender': 2, 'id': 103707, 'name': 'Austin "
#  "Stoker', 'order': 2, 'profile_path': '/ukRtXDLGlmaSE4lAruhAqG7IsLJ.jpg'}, "
#  "{'cast_id': 26, 'character': 'Kolp', 'credit_id': "
#  "'52fe430ec3a3684..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'David Reed', 'credit_id': "
#  "'52fe43da9251416c75020b77', 'gender': 2, 'id': 67685, 'name': 'Richard "
#  "Carlson', 'order': 0, 'profile_path': '/dGBs79xPf6fFI9p0rEiasmn5G3X.jpg'}, "
#  "{'cast_id': 2, 'character': 'Kay Lawrence', 'credit_id': "
#  "'52fe43da9251416c75020b7b', 'gender': 1, 'id': 31169, 'name': 'Julie Adams', "
#  "'order': 1, 'profile_path': '/p6abeZkETxG9h2JdaKwzyesWSFv.jpg'}, {'cast_id': "
#  "3, 'character': 'Mark Williams', 'credit_id': '52fe43da9251416c75020b7f', "
#  "'gender': 2, 'id': 54681, 'name': 'Richard Denning', 'order': 2, "
#  "'profile_path': '/kGYesw34sQkfazqQj3Dy2Ul8lmx.jpg'}, {'cast_id': 4, "
#  "'character': 'Carl Maia', 'credit_id': '52..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': 'Jack Moniker', 'credit_id': "
#  "'52fe450ac3a368484e045017', 'gender': 2, 'id': 2157, 'name': 'Robin "
#  "Williams', 'order': 0, 'profile_path': '/sojtJyIV3lkUeThD7A2oHNm8183.jpg'}, "
#  "{'cast_id': 4, 'character': 'Governor Anthony Cloyden Hayes', 'credit_id': "
#  '\'52fe450ac3a368484e04501b\', \'gender\': 2, \'id\': 11390, \'name\': "Peter '
#  'O\'Toole", \'order\': 1, \'profile_path\': '
#  "'/7esSG4iZHueb5Nh8RBBhtRZLpom.jpg'}, {'cast_id': 5, 'character': 'Barry "
#  "Nye', 'credit_id': '52fe450ac3a368484e04501f', 'gender': 2, 'id': 8872, "
#  "'name': 'Rick Moranis', 'order': 2, 'profile_path': "
#  "'/rVZbTJjM4g0Um6trlLHRiBzBO7t.jpg'}, {'cast_id': 6, 'character': 'Ern..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Adela Quested', 'credit_id': "
#  "'52fe468b9251416c7507ba7b', 'gender': 1, 'id': 351, 'name': 'Judy Davis', "
#  "'order': 0, 'profile_path': '/xQMA72T6yz6ebJXv1pCuZC1fDJo.jpg'}, {'cast_id': "
#  "2, 'character': 'Prof. Godbole', 'credit_id': '52fe468b9251416c7507ba7f', "
#  "'gender': 2, 'id': 12248, 'name': 'Alec Guinness', 'order': 1, "
#  "'profile_path': '/nv3ppxgUQJytFGXZNde4f9ZlshB.jpg'}, {'cast_id': 3, "
#  "'character': 'Mrs. Moore', 'credit_id': '52fe468b9251416c7507ba83', "
#  "'gender': 1, 'id': 3672, 'name': 'Peggy Ashcroft', 'order': 2, "
#  "'profile_path': '/xFJWz7XbWTwkhaAnV29yCUsTc9o.jpg'}, {'cast_id': 4, "
#  "'character': 'Richard Fielding', 'credit_id': '52fe468b9251416c7507ba87', "
#  "'gender': 2, 'id': 1292, 'name': 'James Fox', 'order': 3, 'profile_path': "
#  "'/hhWJskOI5sM8gikgJTQJZidkGRb.jpg'}, {'cast_id': 5, 'character': 'Dr. Aziz "
#  "H. Ahmed', 'credit_id': '52fe468b9251416c7507ba8b', 'gender': 2, 'id': "
#  "78951, 'name': 'Victor Banerjee', 'order': 4, 'profile_path': "
#  "'/s19NsocK35S7RFs1vuS61tK3dET.jpg'}, {'cast_id': 6, 'character': 'Ronny "
#  "Heaslop', 'credit_id': '52fe468b9251416c7507ba8f', 'gender': 2, 'id': 53517, "
#  "'name': 'Nigel Havers', 'order': 5, 'profile_path': "
#  "'/hZNkoh83CUAlOmqMwAz7i1jwWgi.jpg'}, {'cast_id': 7, 'character': 'Maj. "
#  "McBryde', 'credit_id': '52fe468b9251416c7507ba93', 'gender': 2, 'id': 47520, "
#  "'name': 'Michael Culver', 'order': 6, 'profile_path': "
#  "'/njBI1pTMMMlon5LufetA1vHn819.jpg'}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 11, 'character': 'John Finnegan', 'credit_id': "
#  "'52fe44fac3a36847f80b54f1', 'gender': 2, 'id': 4515, 'name': 'Treat "
#  "Williams', 'order': 0, 'profile_path': '/uKejRJTEVOy6IOsJX2mJH3SwbTl.jpg'}, "
#  "{'cast_id': 12, 'character': 'Trillian St. James', 'credit_id': "
#  "'52fe44fac3a36847f80b54f5', 'gender': 1, 'id': 10696, 'name': 'Famke "
#  "Janssen', 'order': 1, 'profile_path': '/9wHWq6Mnfpn8L1diMxjr26ReZWl.jpg'}, "
#  "{'cast_id': 13, 'character': 'Simon Canton', 'credit_id': "
#  "'52fe44fac3a36847f80b54f9', 'gender': 2, 'id': 16293, 'name': 'Anthony "
#  "Heald', 'order': 2, 'profile_path': '/nRXLwMuuv5nUbEz2sFLtEU4zUYg.jpg'}, "
#  "{'cast_id': 14, 'character': 'Joey Pantucci', 'c..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Thomas Barnes', 'credit_id': "
#  "'52fe447fc3a36847f8099a33', 'gender': 2, 'id': 6065, 'name': 'Dennis Quaid', "
#  "'order': 0, 'profile_path': '/fSnnQg8y1LB9yHbn2WuEcUb8i9Y.jpg'}, {'cast_id': "
#  "2, 'character': 'Kent Taylor', 'credit_id': '52fe447fc3a36847f8099a37', "
#  "'gender': 2, 'id': 28657, 'name': 'Matthew Fox', 'order': 1, 'profile_path': "
#  "'/sDwybT6aujgEQhesfg8Mt14dgsN.jpg'}, {'cast_id': 3, 'character': 'Howard "
#  "Lewis', 'credit_id': '52fe447fc3a36847f8099a3b', 'gender': 2, 'id': 2178, "
#  "'name': 'Forest Whitaker', 'order': 2, 'profile_path': "
#  "'/4pMQkelS5lK661m9Kz3oIxLYiyS.jpg'}, {'cast_id': 4, 'character': 'Rex "
#  "Brooks', 'credit_id': '52fe4..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Dorothy', 'credit_id': "
#  "'52fe44b2c3a368484e031a33', 'gender': 1, 'id': 32715, 'name': 'Diana Ross', "
#  "'order': 0, 'profile_path': '/6xVBaLk6mBeneEQSJchsQ276FTX.jpg'}, {'cast_id': "
#  "2, 'character': 'Scarecrow', 'credit_id': '52fe44b2c3a368484e031a37', "
#  "'gender': 2, 'id': 82702, 'name': 'Michael Jackson', 'order': 1, "
#  "'profile_path': '/9nDsffd8kZ2O9MlnIiqWRVausM7.jpg'}, {'cast_id': 3, "
#  "'character': 'Tinman', 'credit_id': '52fe44b2c3a368484e031a3b', 'gender': 2, "
#  "'id': 92899, 'name': 'Nipsey Russell', 'order': 2, 'profile_path': "
#  "'/hKPKPD7opWURQXLa302t3kslarh.jpg'}, {'cast_id': 4, 'character': 'Lion / "
#  "Fleetwood Coup de Ville', 'credit_id..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(('[{\'cast_id\': 1, \'character\': "Michael \'Mike\' Brody", \'credit_id\': '
#  "'52fe47409251416c75092e41', 'gender': 2, 'id': 6065, 'name': 'Dennis Quaid', "
#  "'order': 0, 'profile_path': '/fSnnQg8y1LB9yHbn2WuEcUb8i9Y.jpg'}, {'cast_id': "
#  "2, 'character': 'Kathryn Morgan', 'credit_id': '52fe47419251416c75092e45', "
#  "'gender': 1, 'id': 29710, 'name': 'Bess Armstrong', 'order': 1, "
#  "'profile_path': '/fH9l0jd9uYFPlW8iHKFyQnL3ThW.jpg'}, {'cast_id': 3, "
#  "'character': 'Philip FitzRoyce', 'credit_id': '52fe47419251416c75092e49', "
#  "'gender': 2, 'id': 24743, 'name': 'Simon MacCorkindale', 'order': 2, "
#  "'profile_path': '/pss165HPDGUf6BfPAqNzB0oOf75.jpg'}, {'cast_id': 4, "
#  "'character': 'Ca..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 10, 'character': 'Dracula', 'credit_id': "
#  "'52fe438b9251416c7501484d', 'gender': 2, 'id': 17276, 'name': 'Gerard "
#  "Butler', 'order': 0, 'profile_path': '/i54XoxYieuff2w6MwyfwVUBvmR0.jpg'}, "
#  "{'cast_id': 11, 'character': 'Matthew Van Helsing', 'credit_id': "
#  "'52fe438b9251416c75014851', 'gender': 2, 'id': 290, 'name': 'Christopher "
#  "Plummer', 'order': 1, 'profile_path': '/fauMGxa6dc86nHNenQ8X6DlE6YV.jpg'}, "
#  "{'cast_id': 12, 'character': 'Simon Sheppard', 'credit_id': "
#  "'52fe438b9251416c75014855', 'gender': 2, 'id': 9012, 'name': 'Jonny Lee "
#  "Miller', 'order': 2, 'profile_path': '/70oZd4dPWNAibagHJvRU1Tf9e6h.jpg'}, "
#  "{'cast_id': 13, 'character': 'Mary Heller', '..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 8, 'character': 'Officer Gunther Toody', 'credit_id': "
#  "'53b9f74ec3a3685eb70061a9', 'gender': 2, 'id': 57116, 'name': 'David "
#  "Johansen', 'order': 0, 'profile_path': '/hQq0pmBBcmapA8YPxsgnDuZnEAa.jpg'}, "
#  "{'cast_id': 1, 'character': 'Officer Francis Muldoon', 'credit_id': "
#  "'52fe447a9251416c91012149', 'gender': 2, 'id': 11885, 'name': 'John C. "
#  "McGinley', 'order': 1, 'profile_path': '/6AJL0ylRtJ9vcR57yEenhWHXHFt.jpg'}, "
#  "{'cast_id': 2, 'character': 'Velma Velour', 'credit_id': "
#  "'52fe447a9251416c9101214d', 'gender': 1, 'id': 53122, 'name': 'Fran "
#  "Drescher', 'order': 2, 'profile_path': '/vQxr8CRgyDkH3GTFLwacs9W9tF4.jpg'}, "
#  "{'cast_id': 9, 'character': 'Polic..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Sheriff Bryce Hammond', 'credit_id': "
#  "'52fe4535c3a36847f80c2271', 'gender': 2, 'id': 880, 'name': 'Ben Affleck', "
#  "'order': 0, 'profile_path': '/cPuPt6mYJ83DjvO3hbjNGug6Fbi.jpg'}, {'cast_id': "
#  "2, 'character': 'Dr. Timothy Flyte', 'credit_id': "
#  '\'52fe4535c3a36847f80c2275\', \'gender\': 2, \'id\': 11390, \'name\': "Peter '
#  'O\'Toole", \'order\': 1, \'profile_path\': '
#  "'/7esSG4iZHueb5Nh8RBBhtRZLpom.jpg'}, {'cast_id': 3, 'character': 'Lisa "
#  "Pailey', 'credit_id': '52fe4535c3a36847f80c2279', 'gender': 1, 'id': 16850, "
#  "'name': 'Rose McGowan', 'order': 2, 'profile_path': "
#  "'/llI2Fc6G0wqZlASpIEGWnLViZxD.jpg'}, {'cast_id': 4, 'character': 'Jennifer..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': '', 'credit_id': '53306374c3a3685fac006bd3', "
#  "'gender': 2, 'id': 26457, 'name': 'Matthew Lillard', 'order': 1, "
#  "'profile_path': '/gJsQkX20g0ABquHqVpBJzMXR2JF.jpg'}, {'cast_id': 3, "
#  "'character': '', 'credit_id': '5330637bc3a3685fc3006df7', 'gender': 1, 'id': "
#  "17832, 'name': 'Carla Gugino', 'order': 2, 'profile_path': "
#  "'/xddYLCp8zWLgYcQRck7REEgCUWl.jpg'}, {'cast_id': 4, 'character': 'Tobi', "
#  "'credit_id': '53306388c3a3685fe2006dec', 'gender': 2, 'id': 2387, 'name': "
#  "'Patrick Stewart', 'order': 3, 'profile_path': "
#  "'/wEy5qSDT5jT3ZASc2hbwi59voPL.jpg'}, {'cast_id': 11, 'character': 'Cabbie', "
#  "'credit_id': '53fed2c60e0a2658280002b7', 'gender': 0, 'id': 20632, 'name': "
#  "'Maduka Steady', 'order': 4, 'profile_path': None}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 13, 'character': 'R', 'credit_id': '52fe48649251416c9108ad65', "
#  "'gender': 2, 'id': 3292, 'name': 'Nicholas Hoult', 'order': 0, "
#  "'profile_path': '/27NbnWKzco1CCDHtR2AVVab8Dli.jpg'}, {'cast_id': 11, "
#  "'character': 'Julie Grigio', 'credit_id': '52fe48649251416c9108ad5d', "
#  "'gender': 1, 'id': 20374, 'name': 'Teresa Palmer', 'order': 1, "
#  "'profile_path': '/v9t3baWMoUcdEhec5SkCwa1aiL6.jpg'}, {'cast_id': 12, "
#  "'character': 'Nora Greene', 'credit_id': '52fe48649251416c9108ad61', "
#  "'gender': 1, 'id': 124644, 'name': 'Analeigh Tipton', 'order': 2, "
#  "'profile_path': '/oFTEyLJykoAWtUOT9RPKco3F1FJ.jpg'}, {'cast_id': 16, "
#  "'character': 'M / Marcus', 'credit_id': '52fe486..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'James', 'credit_id': "
#  "'52fe45e89251416c750669e5', 'gender': 2, 'id': 6408, 'name': 'Nick Stahl', "
#  "'order': 0, 'profile_path': '/3IBXRFxLdpk3PrN6ypdiWZi6xe3.jpg'}, {'cast_id': "
#  "2, 'character': 'Tara', 'credit_id': '52fe45e89251416c750669e9', 'gender': "
#  "1, 'id': 1285, 'name': 'AnnaSophia Robb', 'order': 1, 'profile_path': "
#  "'/jktnEA6LUBl4JTh7uPRfUFQFXBn.jpg'}, {'cast_id': 3, 'character': 'Joleen', "
#  "'credit_id': '52fe45e89251416c750669ed', 'gender': 1, 'id': 6885, 'name': "
#  "'Charlize Theron', 'order': 2, 'profile_path': "
#  "'/aHOB9UMgSI7MlXF3GMZaVQXqfQg.jpg'}, {'cast_id': 4, 'character': 'Randall', "
#  "'credit_id': '52fe45e99251416c750669f1', 'gender': 2, 'id': 57755, 'name': "
#  "'Woody Harrelson', 'order': 3, 'profile_path': "
#  "'/1ecdooAHICUhCZKKEKlFtccEmTU.jpg'}, {'cast_id': 5, 'character': 'Mr. "
#  "Reedy', 'credit_id': '52fe45e99251416c750669f5', 'gender': 2, 'id': 2778, "
#  "'name': 'Dennis Hopper', 'order': 4, 'profile_path': "
#  "'/56nj2DfMVU3F9qUagZWMePLbrKF.jpg'}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'James Averill', 'credit_id': "
#  "'52fe43d49251416c7501fcaf', 'gender': 2, 'id': 10823, 'name': 'Kris "
#  "Kristofferson', 'order': 0, 'profile_path': "
#  "'/hiGkNoiAwnUgY9XZ3YhiWMvKngi.jpg'}, {'cast_id': 2, 'character': 'Nathan D. "
#  "Champion', 'credit_id': '52fe43d49251416c7501fcb3', 'gender': 2, 'id': 4690, "
#  "'name': 'Christopher Walken', 'order': 1, 'profile_path': "
#  "'/ysO1GwRzLT9OVAB9Y2SKHxomqDr.jpg'}, {'cast_id': 3, 'character': 'Billy "
#  "Irvine', 'credit_id': '52fe43d49251416c7501fcb7', 'gender': 2, 'id': 5049, "
#  "'name': 'John Hurt', 'order': 2, 'profile_path': "
#  "'/tW6cOElGBdJl8nNrHwL6gvxvdkI.jpg'}, {'cast_id': 4, 'character': 'Ella "
#  "Watson', ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 10, 'character': 'Father', 'credit_id': "
#  "'5923bdacc3a3680426006fde', 'gender': 0, 'id': 1497778, 'name': 'Emmanuel "
#  "Garijo', 'order': 1, 'profile_path': '/cDqKqZg1Fek2neLDoQOQYoQNWhP.jpg'}, "
#  "{'cast_id': 11, 'character': 'Young Adult Son', 'credit_id': "
#  "'5923bdbac3a3680426006feb', 'gender': 2, 'id': 1327993, 'name': 'Tom "
#  "Hudson', 'order': 2, 'profile_path': '/dRekOwP7mrImBB8XAhppzPLNp8R.jpg'}, "
#  "{'cast_id': 12, 'character': 'Child Son', 'credit_id': "
#  "'5923bdc3c3a3680474006504', 'gender': 0, 'id': 1822014, 'name': 'Baptiste "
#  "Goy', 'order': 3, 'profile_path': None}, {'cast_id': 13, 'character': "
#  "'Baby', 'credit_id': '5923bdcac3a36804a300670a', 'gender': 0, 'id': 1822015, "
#  "'name': 'Axel Devillers', 'order': 4, 'profile_path': None}, {'cast_id': 14, "
#  "'character': 'Mother', 'credit_id': '5923bdd5925141055e007cac', 'gender': 0, "
#  "'id': 1515111, 'name': 'Barbara Beretta', 'order': 5, 'profile_path': None}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 20, 'character': 'Archy', 'credit_id': "
#  "'52fe45a49251416c7505d67b', 'gender': 2, 'id': 2983, 'name': 'Mark Strong', "
#  "'order': 0, 'profile_path': '/tr8nXYhY1ZWGmsXuHFHk6MBeL9Q.jpg'}, {'cast_id': "
#  "10, 'character': 'Lenny Cole', 'credit_id': '52fe45a49251416c7505d65b', "
#  "'gender': 2, 'id': 207, 'name': 'Tom Wilkinson', 'order': 1, 'profile_path': "
#  "'/4mxZKgdem0sQ8hJd0Y7TREwq7TJ.jpg'}, {'cast_id': 6, 'character': 'Johnny "
#  "Quid', 'credit_id': '52fe45a49251416c7505d64b', 'gender': 2, 'id': 20286, "
#  "'name': 'Toby Kebbell', 'order': 2, 'profile_path': "
#  "'/wQU3uFk2TWjT2qfs2Z6rkdbWbjx.jpg'}, {'cast_id': 5, 'character': 'One-Two', "
#  "'credit_id': '52fe45a49251416c750..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 18, 'character': 'Liu Jian', 'credit_id': "
#  "'52fe433ac3a36847f8043f37', 'gender': 2, 'id': 1336, 'name': 'Jet Li', "
#  "'order': 0, 'profile_path': '/5himGJzSuLoHwqacTz7sXWqgeMt.jpg'}, {'cast_id': "
#  "19, 'character': 'Jessica Kamen', 'credit_id': '52fe433ac3a36847f8043f3b', "
#  "'gender': 1, 'id': 2233, 'name': 'Bridget Fonda', 'order': 1, "
#  "'profile_path': '/yWxhdN59eksIqyBHdjUcLRgCIaI.jpg'}, {'cast_id': 20, "
#  "'character': 'Insp. Richard', 'credit_id': '52fe433ac3a36847f8043f3f', "
#  "'gender': 2, 'id': 10698, 'name': 'Tch√©ky Karyo', 'order': 2, "
#  "'profile_path': '/9rMF25F5r3Giix9jkwfuUz2utHv.jpg'}, {'cast_id': 21, "
#  "'character': 'Lupo', 'credit_id': '52fe433ac3a3684..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1002, 'character': 'Terri', 'credit_id': "
#  "'52fe4811c3a36847f81569e5', 'gender': 2, 'id': 145131, 'name': 'Jacob "
#  "Wysocki', 'order': 0, 'profile_path': '/hCSwRS4cudr3kHgsSKoAvPYCszT.jpg'}, "
#  "{'cast_id': 1001, 'character': 'Mr. Fitzgerald', 'credit_id': "
#  "'52fe4811c3a36847f81569e1', 'gender': 2, 'id': 4764, 'name': 'John C. "
#  "Reilly', 'order': 1, 'profile_path': '/kUo2TPQp4kOWWvijvkjLl0v9PQB.jpg'}, "
#  "{'cast_id': 1003, 'character': 'Uncle James', 'credit_id': "
#  "'52fe4811c3a36847f81569e9', 'gender': 2, 'id': 85177, 'name': 'Creed "
#  "Bratton', 'order': 2, 'profile_path': '/hUnoHi3mhHMvCm0lRlsxLXGvIPI.jpg'}, "
#  "{'cast_id': 1006, 'character': 'Heather Miles', 'credi..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Marion Davies', 'credit_id': "
#  "'52fe45919251416c91036e73', 'gender': 1, 'id': 205, 'name': 'Kirsten Dunst', "
#  "'order': 0, 'profile_path': '/wBXvh6PJd0IUVNpvatPC1kzuHtm.jpg'}, {'cast_id': "
#  "2, 'character': 'W. R. Hearst', 'credit_id': '52fe45919251416c91036e77', "
#  "'gender': 2, 'id': 52995, 'name': 'Edward Herrmann', 'order': 1, "
#  "'profile_path': '/3AGRAverIuT6kgSfGQPiY55QZzG.jpg'}, {'cast_id': 3, "
#  "'character': 'Charlie Chaplin', 'credit_id': '52fe45919251416c91036e7b', "
#  "'gender': 2, 'id': 1926, 'name': 'Eddie Izzard', 'order': 2, 'profile_path': "
#  "'/j5hzBqmcyWG2GC754uACCoNgAvS.jpg'}, {'cast_id': 4, 'character': 'Thomas "
#  "Ince', 'credit_id': '52fe45919251416c91036e7f', 'gender': 2, 'id': 2130, "
#  "'name': 'Cary Elwes', 'order': 3, 'profile_path': "
#  "'/wmvYoJHStQeQzrpqOM9tkvf1wwF.jpg'}, {'cast_id': 5, 'character': 'Elinor "
#  "Glyn', 'credit_id': '52fe45919251416c91036e83', 'gender': 1, 'id': 34901, "
#  "'name': 'Joanna Lumley', 'order': 4, 'profile_path': "
#  "'/2RFXqaFpeN9WmhfAyNaumz0rZUV.jpg'}, {'cast_id': 6, 'character': 'Louella "
#  "Parsons', 'credit_id': '52fe45919251416c91036e87', 'gender': 1, 'id': 7906, "
#  "'name': 'Jennifer Tilly', 'order': 5, 'profile_path': "
#  "'/bNB0BTnPAdAAHuCQSprMk4smBMD.jpg'}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 7, 'character': 'Nick Dunne', 'credit_id': "
#  "'52fe4d7fc3a368484e1ec763', 'gender': 2, 'id': 880, 'name': 'Ben Affleck', "
#  "'order': 0, 'profile_path': '/cPuPt6mYJ83DjvO3hbjNGug6Fbi.jpg'}, {'cast_id': "
#  "8, 'character': 'Amy Dunne', 'credit_id': '52fe4d7fc3a368484e1ec767', "
#  "'gender': 1, 'id': 10882, 'name': 'Rosamund Pike', 'order': 1, "
#  "'profile_path': '/wevcai4tcGA5niawACntEzgZsKN.jpg'}, {'cast_id': 27, "
#  "'character': 'Margo Dunne', 'credit_id': '542f5d5d0e0a264f07000b82', "
#  "'gender': 1, 'id': 1308445, 'name': 'Carrie Coon', 'order': 2, "
#  "'profile_path': '/aX7kfLrSYWK7s9KvjldO1JYCbPv.jpg'}, {'cast_id': 10, "
#  "'character': 'Desi Collins', 'credit_id': '52fe4d7f..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Robin', 'credit_id': "
#  "'52fe46aec3a36847f810c3eb', 'gender': 1, 'id': 17832, 'name': 'Carla "
#  "Gugino', 'order': 0, 'profile_path': '/xddYLCp8zWLgYcQRck7REEgCUWl.jpg'}, "
#  "{'cast_id': 2, 'character': 'Ned', 'credit_id': '52fe46aec3a36847f810c3ef', "
#  "'gender': 2, 'id': 23626, 'name': 'Liev Schreiber', 'order': 1, "
#  "'profile_path': '/qFn3npmqd1qaYOk6yohmi3FbPhc.jpg'}, {'cast_id': 3, "
#  "'character': 'Jeannie', 'credit_id': '52fe46aec3a36847f810c3f3', 'gender': "
#  "1, 'id': 9994, 'name': 'Helen Hunt', 'order': 2, 'profile_path': "
#  "'/ws1ClG9BBUIVLZRYTNKconJn9Sy.jpg'}, {'cast_id': 4, 'character': 'Ernie', "
#  "'credit_id': '52fe46aec3a36847f810c3f7', 'gend..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 14, 'character': 'Thomas More', 'credit_id': "
#  "'52fe4285c3a36847f8025901', 'gender': 2, 'id': 13324, 'name': 'Paul "
#  "Scofield', 'order': 0, 'profile_path': '/gt4YFHyhE29CfpiZxknPy0aAGx.jpg'}, "
#  "{'cast_id': 15, 'character': 'Alice More', 'credit_id': "
#  "'52fe4285c3a36847f8025905', 'gender': 1, 'id': 13325, 'name': 'Wendy "
#  "Hiller', 'order': 1, 'profile_path': '/tJoIGdsqvjx01Cz3akTr7kaETa5.jpg'}, "
#  "{'cast_id': 16, 'character': 'Thomas Cromwell', 'credit_id': "
#  "'52fe4285c3a36847f8025909', 'gender': 2, 'id': 7192, 'name': 'Leo McKern', "
#  "'order': 2, 'profile_path': '/sLaiG34eu3y2AwuikxNlvqDzQYW.jpg'}, {'cast_id': "
#  "17, 'character': 'King Henry VIII', 'credit_id': ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 7, 'character': 'Ed', 'credit_id': '52fe436fc3a36847f8054175', "
#  "'gender': 2, 'id': 3036, 'name': 'John Cusack', 'order': 0, 'profile_path': "
#  "'/uKydQYuZ9TnCzvbQLtj6j98vWAT.jpg'}, {'cast_id': 8, 'character': 'Rhodes', "
#  "'credit_id': '52fe436fc3a36847f8054179', 'gender': 2, 'id': 11477, 'name': "
#  "'Ray Liotta', 'order': 1, 'profile_path': "
#  "'/o4jJSH3sri9dSIJwsCgT4de1535.jpg'}, {'cast_id': 9, 'character': 'Paris', "
#  "'credit_id': '52fe436fc3a36847f805417d', 'gender': 1, 'id': 2956, 'name': "
#  "'Amanda Peet', 'order': 2, 'profile_path': "
#  "'/81KzrntoeEztNpfhCYNgfOtI3kU.jpg'}, {'cast_id': 10, 'character': 'Larry', "
#  "'credit_id': '52fe436fc3a36847f8054181', 'gender': 2..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'La b√™te', 'credit_id': "
#  "'52fe4d629251416c91114269', 'gender': 2, 'id': 1925, 'name': 'Vincent "
#  "Cassel', 'order': 0, 'profile_path': '/yTTyX7xziiMibm0nzcH5z6xxLLv.jpg'}, "
#  "{'cast_id': 3, 'character': 'La belle', 'credit_id': "
#  "'52fe4d629251416c9111426d', 'gender': 1, 'id': 121529, 'name': 'L√©a "
#  "Seydoux', 'order': 1, 'profile_path': '/2ZyK2a1fKvUXlhKBORpqcMd4Uot.jpg'}, "
#  '{\'cast_id\': 4, \'character\': "Belle\'s father", \'credit_id\': '
#  "'52fe4d629251416c91114271', 'gender': 2, 'id': 18177, 'name': 'Andr√© "
#  "Dussollier', 'order': 2, 'profile_path': "
#  "'/rKZXoZJBUMKRbACbAGEat7wvAr7.jpg'}, {'cast_id': 5, 'character': 'Perducas', "
#  "'credit_i..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Dr. Seth Ember', 'credit_id': "
#  "'52fe4eb5c3a36847f82a2d07', 'gender': 2, 'id': 6383, 'name': 'Aaron "
#  "Eckhart', 'order': 0, 'profile_path': '/aRSofX2rMpOhPanB9Wh7veYmFn4.jpg'}, "
#  "{'cast_id': 2, 'character': 'Cameron', 'credit_id': "
#  "'52fe4eb5c3a36847f82a2d0b', 'gender': 2, 'id': 934173, 'name': 'David "
#  "Mazouz', 'order': 1, 'profile_path': '/13lIdP9RSdK44lpJtKz3OlYCMxp.jpg'}, "
#  "{'cast_id': 3, 'character': 'Camilla', 'credit_id': "
#  "'52fe4eb5c3a36847f82a2d0f', 'gender': 1, 'id': 5887, 'name': 'Catalina "
#  "Sandino Moreno', 'order': 2, 'profile_path': "
#  "'/6TsJDZOmhBxfTKFp6ldC68OW65n.jpg'}, {'cast_id': 4, 'character': 'Lindsey', "
#  "'credit_id': '5..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 10, 'character': 'Dr. Frederick Treves', 'credit_id': "
#  "'52fe4326c3a36847f803df8f', 'gender': 2, 'id': 4173, 'name': 'Anthony "
#  "Hopkins', 'order': 0, 'profile_path': '/jdoBTIru71FbPuHGEgox5RVmIO0.jpg'}, "
#  "{'cast_id': 11, 'character': 'John Merrick', 'credit_id': "
#  "'52fe4326c3a36847f803df93', 'gender': 2, 'id': 5049, 'name': 'John Hurt', "
#  "'order': 1, 'profile_path': '/tW6cOElGBdJl8nNrHwL6gvxvdkI.jpg'}, {'cast_id': "
#  "12, 'character': 'Mrs. Kendal', 'credit_id': '52fe4326c3a36847f803df97', "
#  "'gender': 1, 'id': 10774, 'name': 'Anne Bancroft', 'order': 2, "
#  "'profile_path': '/4VMhut6tvXqXBmMGFRjXbbImAZW.jpg'}, {'cast_id': 13, "
#  "'character': 'Carr Gomm', 'credit_id..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 16, 'character': 'Pam Roberts', 'credit_id': "
#  "'52fe4523c3a36847f80bea1f', 'gender': 1, 'id': 197057, 'name': 'Melanie "
#  "Kinnaman', 'order': 0, 'profile_path': None}, {'cast_id': 17, 'character': "
#  "'Tommy Jarvis', 'credit_id': '52fe4523c3a36847f80bea23', 'gender': 2, 'id': "
#  "162927, 'name': 'John Shepherd', 'order': 1, 'profile_path': None}, "
#  "{'cast_id': 18, 'character': 'Reggie', 'credit_id': "
#  "'52fe4523c3a36847f80bea27', 'gender': 2, 'id': 1212555, 'name': 'Shavar "
#  "Ross', 'order': 2, 'profile_path': None}, {'cast_id': 19, 'character': "
#  "'Matthew Letter', 'credit_id': '52fe4523c3a36847f80bea2b', 'gender': 2, "
#  "'id': 745, 'name': 'Richard Young', 'order': 3..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': '', 'credit_id': '54359020c3a36836e7000276', "
#  "'gender': 2, 'id': 1062262, 'name': 'Stanislav Boklan', 'order': 1, "
#  "'profile_path': '/lmvcFumjDxOmVqJAArdgYKbUmb1.jpg'}, {'cast_id': 2, "
#  "'character': '', 'credit_id': '5435904b0e0a2643dd00018a', 'gender': 0, 'id': "
#  "49491, 'name': 'Jeff Burrell', 'order': 2, 'profile_path': "
#  "'/cQ6z77rmiV1iZTTORjSpFJXV5bw.jpg'}, {'cast_id': 3, 'character': '', "
#  "'credit_id': '543590720e0a2624b90001c2', 'gender': 0, 'id': 1372330, 'name': "
#  "'Anton Sviatoslav Greene', 'order': 3, 'profile_path': None}, {'cast_id': 4, "
#  "'character': '', 'credit_id': '543590850e0a264d730002a5', 'gender': 2, 'id': "
#  "1132702, 'name': 'Aleksandr Kobzar', 'order': 4, 'profile_path': "
#  "'/n1h0HKdc7IMlqd3T3XfhZQwatUl.jpg'}, {'cast_id': 5, 'character': '', "
#  "'credit_id': '54359099c3a368422100026f', 'gender': 0, 'id': 1045993, 'name': "
#  "'Oleg Primogenov', 'order': 5, 'profile_path': None}, {'cast_id': 6, "
#  "'character': 'Natalka', 'credit_id': '581353c3925141543e025aeb', 'gender': "
#  "1, 'id': 1619846, 'name': '–í–µ—Ä–æ–Ω—ñ–∫–∞ –®–æ—Å—Ç–∞–∫', 'order': 6, "
#  "'profile_path': '/7Trj3Jp5zKySztrX18Rs452EQH1.jpg'}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(('[{\'cast_id\': 1, \'character\': "Rudolph \'Rudy\' Russo", \'credit_id\': '
#  "'52fe45f89251416c75068a9d', 'gender': 2, 'id': 6856, 'name': 'Kurt Russell', "
#  "'order': 0, 'profile_path': '/rlnFuNkisPpuypARI7QaGCmOY6V.jpg'}, {'cast_id': "
#  "2, 'character': 'Roy L. Fuchs / Luke Fuchs', 'credit_id': "
#  "'52fe45f89251416c75068aa1', 'gender': 2, 'id': 5251, 'name': 'Jack Warden', "
#  "'order': 1, 'profile_path': '/pD98exbwlD4f9QmQd0N8Sa7j6pw.jpg'}, {'cast_id': "
#  "4, 'character': 'Jim, the Mechanic', 'credit_id': "
#  "'52fe45f89251416c75068aab', 'gender': 2, 'id': 1735, 'name': 'Frank McRae', "
#  "'order': 2, 'profile_path': '/piXgVU3tnR6hGvgeZjeqUqKsfi5.jpg'}, {'cast_id': "
#  "5, 'character': 'Jef..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(('[{\'cast_id\': 1, \'character\': \'Cpl. "Average Joe" Bauers/"Not Sure"\', '
#  "'credit_id': '52fe4481c3a36847f809a179', 'gender': 2, 'id': 36422, 'name': "
#  "'Luke Wilson', 'order': 0, 'profile_path': "
#  "'/n7CRA7h1z3FVOzBJ5EjfSrPQbvl.jpg'}, {'cast_id': 2, 'character': 'Rita', "
#  "'credit_id': '52fe4481c3a36847f809a17d', 'gender': 1, 'id': 52792, 'name': "
#  "'Maya Rudolph', 'order': 1, 'profile_path': "
#  "'/qLDuXku39c4uwVf3h2GjFqwZqik.jpg'}, {'cast_id': 3, 'character': 'Frito "
#  "Pendejo', 'credit_id': '52fe4481c3a36847f809a181', 'gender': 2, 'id': 51298, "
#  "'name': 'Dax Shepard', 'order': 2, 'profile_path': "
#  "'/50RfzslPEtaFdctKGU8GbWSheDZ.jpg'}, {'cast_id': 23, 'character': 'President ..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'Ray Gaines', 'credit_id': "
#  "'52fe4ea59251416c91138cfd', 'gender': 2, 'id': 18918, 'name': 'Dwayne "
#  "Johnson', 'order': 0, 'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'}, "
#  "{'cast_id': 1, 'character': 'Blake Gaines', 'credit_id': "
#  "'52fe4ea59251416c91138cf9', 'gender': 1, 'id': 109513, 'name': 'Alexandra "
#  "Daddario', 'order': 1, 'profile_path': '/s544zfrPI1Dnk60t1x1KUXF4iH3.jpg'}, "
#  "{'cast_id': 4, 'character': 'Emma Gaines', 'credit_id': "
#  "'534ff7b4c3a3681cae0010e3', 'gender': 1, 'id': 17832, 'name': 'Carla "
#  "Gugino', 'order': 2, 'profile_path': '/xddYLCp8zWLgYcQRck7REEgCUWl.jpg'}, "
#  "{'cast_id': 8, 'character': 'Daniel Reddick', 'credit_i..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': 'Blade', 'credit_id': "
#  "'52fe45fd9251416c910455f9', 'gender': 2, 'id': 10814, 'name': 'Wesley "
#  "Snipes', 'order': 0, 'profile_path': '/hQ6EBa6vgu7HoZpzms8Y10VL5Iw.jpg'}, "
#  "{'cast_id': 4, 'character': 'Whistler', 'credit_id': "
#  "'52fe45fd9251416c910455fd', 'gender': 2, 'id': 10823, 'name': 'Kris "
#  "Kristofferson', 'order': 1, 'profile_path': "
#  "'/hiGkNoiAwnUgY9XZ3YhiWMvKngi.jpg'}, {'cast_id': 5, 'character': 'Drake', "
#  "'credit_id': '52fe45fd9251416c91045601', 'gender': 2, 'id': 10862, 'name': "
#  "'Dominic Purcell', 'order': 2, 'profile_path': "
#  "'/dyFc8VuAtLQFjL0rKWZuztdBEoT.jpg'}, {'cast_id': 6, 'character': 'Abigail "
#  "Whistler', 'credit_id': '52f..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 4, 'character': 'Alex', 'credit_id': "
#  "'52fe4329c3a36847f803efc7', 'gender': 2, 'id': 20478, 'name': 'Gabe Nevins', "
#  "'order': 0, 'profile_path': None}, {'cast_id': 5, 'character': 'Jennifer', "
#  "'credit_id': '52fe4329c3a36847f803efcb', 'gender': 1, 'id': 20480, 'name': "
#  "'Taylor Momsen', 'order': 1, 'profile_path': "
#  "'/vlPYYz7xAifBron9GLavPrleAWN.jpg'}, {'cast_id': 6, 'character': 'Jared', "
#  "'credit_id': '52fe4329c3a36847f803efcf', 'gender': 2, 'id': 20481, 'name': "
#  "'Jake Miller', 'order': 2, 'profile_path': None}, {'cast_id': 18, "
#  "'character': 'Detective Richard Liu', 'credit_id': "
#  "'52fe4329c3a36847f803f015', 'gender': 0, 'id': 20479, 'name': 'Daniel Liu'..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': 'Squanto', 'credit_id': "
#  "'52fe4700c3a368484e0af959', 'gender': 2, 'id': 33527, 'name': 'Adam Beach', "
#  "'order': 0, 'profile_path': '/83RxYduQiVZ19iJn4sC66jO38KL.jpg'}, {'cast_id': "
#  "4, 'character': 'Mooshawset', 'credit_id': '52fe4700c3a368484e0af95d', "
#  "'gender': 0, 'id': 240609, 'name': 'Sheldon Peters Wolfchild', 'order': 1, "
#  "'profile_path': None}, {'cast_id': 5, 'character': 'Nakooma', 'credit_id': "
#  "'52fe4700c3a368484e0af961', 'gender': 1, 'id': 65529, 'name': 'Irene "
#  "Bedard', 'order': 2, 'profile_path': '/eUX06X7ZpioIO7rHRsaAyNzL646.jpg'}, "
#  "{'cast_id': 6, 'character': 'Epenow', 'credit_id': "
#  "'52fe4700c3a368484e0af965', 'gender': 2, ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': '–ö–∞—Ç—è', 'credit_id': "
#  "'52fe447c9251416c910126bd', 'gender': 1, 'id': 108046, 'name': 'Polina "
#  "Filonenko', 'order': 0, 'profile_path': '/4NpwHPsXviSzfLRAR44ZAfRc7Z3.jpg'}, "
#  "{'cast_id': 2, 'character': '–ñ–∞–Ω–Ω–∞', 'credit_id': "
#  "'52fe447c9251416c910126c1', 'gender': 1, 'id': 108047, 'name': 'Agniya "
#  "Kuznetsova', 'order': 1, 'profile_path': "
#  "'/iB2i7IBOzFuynjalolOIL3czMYC.jpg'}, {'cast_id': 3, 'character': '–í–∏–∫–∞', "
#  "'credit_id': '52fe447c9251416c910126c5', 'gender': 1, 'id': 108048, 'name': "
#  "'Olga Shuvalova', 'order': 2, 'profile_path': "
#  "'/p8mlG7TBzJ426uxVAzoURFwRHNL.jpg'}, {'cast_id': 5, 'character': '', "
#  "'credit_id': '52fe447..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Jenny', 'credit_id': "
#  "'52fe45739251416c75056ff9', 'gender': 1, 'id': 17521, 'name': 'Kelly "
#  "Reilly', 'order': 0, 'profile_path': '/utp6IT1cLk80RgJzehBIWkSQ8FJ.jpg'}, "
#  "{'cast_id': 2, 'character': 'Steve', 'credit_id': "
#  "'52fe45739251416c75056ffd', 'gender': 2, 'id': 17288, 'name': 'Michael "
#  "Fassbender', 'order': 1, 'profile_path': "
#  "'/oexNPLumoFpazzzUqzBSDDYiUg1.jpg'}, {'cast_id': 3, 'character': 'Abi', "
#  "'credit_id': '52fe45739251416c75057001', 'gender': 0, 'id': 85064, 'name': "
#  "'Tara Ellis', 'order': 2, 'profile_path': None}, {'cast_id': 4, 'character': "
#  "'Brett', 'credit_id': '52fe45739251416c75057005', 'gender': 2, 'id': 85065, "
#  '\'..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Gabe', 'credit_id': "
#  "'52fe46da9251416c75085b6f', 'gender': 2, 'id': 27972, 'name': 'Josh "
#  "Hutcherson', 'order': 0, 'profile_path': "
#  "'/fuLYoaiiFhkJzAVj5jOtdZ8FlEl.jpg'}, {'cast_id': 2, 'character': 'Rosemary', "
#  "'credit_id': '52fe46da9251416c75085b73', 'gender': 1, 'id': 88496, 'name': "
#  "'Charlie Ray', 'order': 1, 'profile_path': "
#  "'/dMKWDaWQmbUzD4dLyzZL1mcQM9Z.jpg'}, {'cast_id': 3, 'character': 'Adam', "
#  "'credit_id': '52fe46da9251416c75085b77', 'gender': 2, 'id': 11367, 'name': "
#  "'Bradley Whitford', 'order': 2, 'profile_path': "
#  "'/66brylvzWLg94TRMd6QFrVyMOei.jpg'}, {'cast_id': 4, 'character': 'Leslie', "
#  "'credit_id': '52fe46da9251416c750..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Marcus Aquila', 'credit_id': "
#  "'52fe4797c3a36847f813de9d', 'gender': 2, 'id': 38673, 'name': 'Channing "
#  "Tatum', 'order': 0, 'profile_path': '/5L7BSYbzM8iizvIrS8EaaZoDrI3.jpg'}, "
#  "{'cast_id': 2, 'character': 'Guern', 'credit_id': "
#  "'52fe4797c3a36847f813dea1', 'gender': 2, 'id': 2983, 'name': 'Mark Strong', "
#  "'order': 1, 'profile_path': '/tr8nXYhY1ZWGmsXuHFHk6MBeL9Q.jpg'}, {'cast_id': "
#  "3, 'character': 'Esca', 'credit_id': '52fe4797c3a36847f813dea5', 'gender': "
#  "2, 'id': 478, 'name': 'Jamie Bell', 'order': 2, 'profile_path': "
#  "'/7HgepK5YE8u0xrv3lJZjaEoENwl.jpg'}, {'cast_id': 4, 'character': 'Aquila', "
#  "'credit_id': '52fe4797c3a36847f813dea9', ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Evalita', 'credit_id': "
#  '\'52fe4408c3a368484e00bb19\', \'gender\': 1, \'id\': 821, \'name\': "Beverly '
#  'D\'Angelo", \'order\': 0, \'profile_path\': '
#  "'/fkedkicdG9o9axNqGs5tcTFxglw.jpg'}, {'cast_id': 2, 'character': 'Orville', "
#  "'credit_id': '52fe4408c3a368484e00bb1d', 'gender': 2, 'id': 2222, 'name': "
#  "'Beau Bridges', 'order': 1, 'profile_path': "
#  "'/xv6sDCHxHvBgCK4y96H32kxgcdr.jpg'}, {'cast_id': 3, 'character': 'Sara Lee', "
#  "'credit_id': '52fe4408c3a368484e00bb21', 'gender': 1, 'id': 41249, 'name': "
#  "'Tess Harper', 'order': 2, 'profile_path': "
#  "'/gJT9fBX04LjmbOzOzYcNbA2ZLF1.jpg'}, {'cast_id': 4, 'character': 'Harmony', "
#  "'credit_id': '52fe4..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 4, 'character': 'Emma Bovary', 'credit_id': "
#  "'52fe435cc3a36847f804e9bd', 'gender': 1, 'id': 17882, 'name': 'Isabelle "
#  "Huppert', 'order': 0, 'profile_path': '/wGG9v1Uci3sfrbjt0bRXkLrTqjY.jpg'}, "
#  "{'cast_id': 12, 'character': 'Charles Bovary', 'credit_id': "
#  "'52fe435cc3a36847f804e9df', 'gender': 2, 'id': 35527, 'name': "
#  "'Jean-Fran√ßois Balmer', 'order': 1, 'profile_path': "
#  "'/cNPMUPwVrKHp6AMuH8DuutZ6WUV.jpg'}, {'cast_id': 6, 'character': 'Rodolphe "
#  "Boulanger', 'credit_id': '52fe435cc3a36847f804e9c1', 'gender': 2, 'id': "
#  "24487, 'name': 'Christophe Malavoy', 'order': 2, 'profile_path': "
#  "'/wXjfq6dK6HlFVsch6La8zM3Yq9p.jpg'}, {'cast_id': 7, 'character': 'M. "
# ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'George Dunlap', 'credit_id': "
#  "'52fe4842c3a36847f815e705', 'gender': 0, 'id': 3926, 'name': 'Albert "
#  "Finney', 'order': 0, 'profile_path': '/2BTzSQUa3RXPqeeNjbJqnyIBePE.jpg'}, "
#  "{'cast_id': 2, 'character': 'Faith Dunlap', 'credit_id': "
#  "'52fe4842c3a36847f815e709', 'gender': 1, 'id': 3092, 'name': 'Diane Keaton', "
#  "'order': 1, 'profile_path': '/fzgUMnbOkxC6E3EFcYHWHFaiKyp.jpg'}, {'cast_id': "
#  "3, 'character': 'Sandy', 'credit_id': '52fe4842c3a36847f815e70d', 'gender': "
#  "1, 'id': 650, 'name': 'Karen Allen', 'order': 2, 'profile_path': "
#  "'/6TzVbX52cAOqe9LH6GZ5xutbW5G.jpg'}, {'cast_id': 4, 'character': 'Frank "
#  "Henderson', 'credit_id': '52fe4842c3..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'Mother', 'credit_id': "
#  "'52fe4b33c3a368484e17ce97', 'gender': 0, 'id': 1153105, 'name': 'Reem "
#  "Abdullah', 'order': 0, 'profile_path': '/r6ocmXYapMZ2KI5VSZJDXvVAabg.jpg'}, "
#  "{'cast_id': 3, 'character': 'Wadjda', 'credit_id': "
#  "'52fe4b33c3a368484e17ce9b', 'gender': 0, 'id': 1153106, 'name': 'Waad "
#  "Mohammed', 'order': 1, 'profile_path': '/sNywJQGe7g7l7JTbAGb8cJLPcpm.jpg'}, "
#  "{'cast_id': 4, 'character': 'Abdullah', 'credit_id': "
#  "'52fe4b33c3a368484e17ce9f', 'gender': 0, 'id': 1153107, 'name': "
#  "'Abdullrahman Algohani', 'order': 2, 'profile_path': None}, {'cast_id': 11, "
#  "'character': 'Ms. Hussa', 'credit_id': '52fe4b33c3a368484e17cec7', 'gender..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 5, 'character': 'Sam Witwicky', 'credit_id': "
#  "'52fe44a3c3a36847f80a19f3', 'gender': 2, 'id': 10959, 'name': 'Shia "
#  "LaBeouf', 'order': 0, 'profile_path': '/anP0tygzniIok6L3OxcSZ9TYCF3.jpg'}, "
#  "{'cast_id': 6, 'character': 'Mikaela Banes', 'credit_id': "
#  "'52fe44a3c3a36847f80a19f7', 'gender': 1, 'id': 19537, 'name': 'Megan Fox', "
#  "'order': 1, 'profile_path': '/yOnFnJmVw4RuGjcTNREFBso7pEp.jpg'}, {'cast_id': "
#  "7, 'character': 'Captain Lennox', 'credit_id': '52fe44a3c3a36847f80a19fb', "
#  "'gender': 2, 'id': 19536, 'name': 'Josh Duhamel', 'order': 2, "
#  "'profile_path': '/hi5OzlZAwf22xRRPLFbKnXNoZ9L.jpg'}, {'cast_id': 8, "
#  "'character': 'College Professor', 'credit_id':..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': '', 'credit_id': '52fe49a6c3a368484e136369', "
#  "'gender': 0, 'id': 585012, 'name': 'James Abourezk', 'order': 0, "
#  "'profile_path': None}, {'cast_id': 4, 'character': '', 'credit_id': "
#  "'52fe49a6c3a368484e13636d', 'gender': 2, 'id': 6449, 'name': 'Warren "
#  "Beatty', 'order': 1, 'profile_path': '/1fsYRe1WhIohbfk8qHmjMcuCXeJ.jpg'}, "
#  "{'cast_id': 5, 'character': '', 'credit_id': '52fe49a6c3a368484e136371', "
#  "'gender': 0, 'id': 585013, 'name': 'Chip Berlet', 'order': 2, "
#  "'profile_path': None}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Britt Reid / Green Hornet', 'credit_id': "
# ...
#  "{'cast_id': 15, 'character': 'Karen Collucci', 'credit_id': "
#  "'52fe4551c3a36847f80c771d', 'gender': 1, 'id': 36190, 'name': 'Edie Falco', "
#  "'order': 2, 'profile_path': '/3cPF1o5oag20UXtCYkZeCTtcTFx.jpg'}, {'cast_id': "
#  "17, 'character': 'Felicia', 'credit_i..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Bo Laramie', 'credit_id': "
#  "'52fe466e9251416c750780f1', 'gender': 2, 'id': 6614, 'name': 'Cole Hauser', "
#  "'order': 0, 'profile_path': '/2izzcOrZpt22ObHjSNq3qRhrGHu.jpg'}, {'cast_id': "
#  "2, 'character': 'Abby Laramie', 'credit_id': '52fe466e9251416c750780f5', "
#  "'gender': 1, 'id': 17346, 'name': 'Robin Tunney', 'order': 1, "
#  "'profile_path': '/oQGr5vfYbkarmJQmhGmSpIhSapL.jpg'}, {'cast_id': 3, "
#  "'character': 'Detective Burton', 'credit_id': '52fe466e9251416c750780f9', "
#  "'gender': 2, 'id': 1117, 'name': 'Dennis Farina', 'order': 2, "
#  "'profile_path': '/o649nAtUimSZxEV6xa5JbMSgsED.jpg'}, {'cast_id': 4, "
#  "'character': 'Wendell Stokes', 'credit_id': '5..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 4, 'character': 'Hal', 'credit_id': '52fe45d9c3a368484e0724e3', "
#  "'gender': 2, 'id': 12950, 'name': 'George Kennedy', 'order': 0, "
#  "'profile_path': '/vNYRh8f0QuA2eK8ahKftOBxtDN7.jpg'}, {'cast_id': 5, "
#  "'character': 'David', 'credit_id': '52fe45d9c3a368484e0724e7', 'gender': 2, "
#  "'id': 21479, 'name': 'Andrew Stevens', 'order': 1, 'profile_path': "
#  "'/jaWFCqWahZeUimpEU2GJStm6pKI.jpg'}, {'cast_id': 6, 'character': 'Sue', "
#  "'credit_id': '52fe45d9c3a368484e0724eb', 'gender': 1, 'id': 97881, 'name': "
#  "'Starr Andreeff', 'order': 2, 'profile_path': None}, {'cast_id': 7, "
#  "'character': 'Linda', 'credit_id': '52fe45d9c3a368484e0724ef', 'gender': 1, "
#  "'id': 103582, 'name..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'Driver', 'credit_id': "
#  "'52fe460a9251416c7506b0ab', 'gender': 0, 'id': 557854, 'name': 'Mania "
#  "Akbari', 'order': 0, 'profile_path': None}, {'cast_id': 3, 'character': "
#  "'Amin', 'credit_id': '52fe460a9251416c7506b0af', 'gender': 0, 'id': 557856, "
#  "'name': 'Amin Maher', 'order': 1, 'profile_path': None}, {'cast_id': 4, "
#  "'character': '', 'credit_id': '52fe460a9251416c7506b0b3', 'gender': 0, 'id': "
#  "557857, 'name': 'Kamran Adl', 'order': 2, 'profile_path': None}, {'cast_id': "
#  "5, 'character': '', 'credit_id': '52fe460a9251416c7506b0b7', 'gender': 0, "
#  "'id': 557858, 'name': 'Roya Arabshahi', 'order': 3, 'profile_path': None}]"), key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 1, 'character': 'Father', 'credit_id': "
#  "'52fe489fc3a36847f81711ab', 'gender': 2, 'id': 1206, 'name': 'Jason "
#  "Alexander', 'order': 0, 'profile_path': '/ernpSXp2RnkzeV14OEEKXRq1yND.jpg'}, "
#  "{'cast_id': 2, 'character': 'Mother', 'credit_id': "
#  "'52fe489fc3a36847f81711af', 'gender': 1, 'id': 2453, 'name': 'Mary "
#  "Steenburgen', 'order': 1, 'profile_path': "
#  "'/yJhfuqS3yXW7kLSyvRU6n3b35mq.jpg'}, {'cast_id': 3, 'character': 'Serena', "
#  "'credit_id': '52fe489fc3a36847f81711b3', 'gender': 1, 'id': 368, 'name': "
#  "'Reese Witherspoon', 'order': 2, 'profile_path': "
#  "'/a3o8T1P6yy4KWL7wZG6HuDeuh5n.jpg'}, {'cast_id': 4, 'character': 'Boyd', "
#  "'credit_id': '52fe489fc3a36847f..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': 'Nisi', 'credit_id': "
#  "'52fe477a9251416c7509aeb1', 'gender': 1, 'id': 4587, 'name': 'Halle Berry', "
#  "'order': 0, 'profile_path': '/AmCXHowNbUXpNf41dNrxNB0naM2.jpg'}, {'cast_id': "
#  "4, 'character': 'Mr. Donald Blakemore', 'credit_id': "
#  "'52fe477b9251416c7509aeb5', 'gender': 2, 'id': 2641, 'name': 'Martin "
#  "Landau', 'order': 1, 'profile_path': '/ylT7pqkcPNsHloe2dJsePFSoIkE.jpg'}, "
#  "{'cast_id': 5, 'character': 'Manley', 'credit_id': "
#  "'52fe477b9251416c7509aeb9', 'gender': 2, 'id': 385, 'name': 'Ian "
#  "Richardson', 'order': 2, 'profile_path': "
#  "'/lcBldPUneC5Vzjhkh4btVCSjXhS.jpg'}, {'cast_id': 6, 'character': 'Mickey', "
#  "'credit_id': '52fe477b92514..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 18, 'character': 'Sara Johnson', 'credit_id': "
#  "'52fe4533c3a36847f80c1ccf', 'gender': 1, 'id': 12041, 'name': 'Julia "
#  "Stiles', 'order': 0, 'profile_path': '/qkCdQIHFDmbxCjp4F1x32qvaXeu.jpg'}, "
#  "{'cast_id': 21, 'character': 'Derek Reynolds', 'credit_id': "
#  "'52fe4533c3a36847f80c1cdf', 'gender': 2, 'id': 11868, 'name': 'Sean Patrick "
#  "Thomas', 'order': 1, 'profile_path': '/AoRsY430MigMRDm9R8jgDo1JrMo.jpg'}, "
#  "{'cast_id': 22, 'character': 'Chenille Reynolds', 'credit_id': "
#  "'52fe4533c3a36847f80c1ce3', 'gender': 1, 'id': 11703, 'name': 'Kerry "
#  "Washington', 'order': 2, 'profile_path': "
#  "'/yufNCkn9YuYei9ThzSgApczUe4K.jpg'}, {'cast_id': 23, 'character': 'Malakai', ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 3, 'character': 'The Thief of Bagdad', 'credit_id': "
#  "'52fe45bec3a368484e06c6db', 'gender': 0, 'id': 109088, 'name': 'Douglas "
#  "Fairbanks', 'order': 0, 'profile_path': '/l8DQc2xfFwXt5Wylj2AseWmqrMt.jpg'}, "
#  "{'cast_id': 4, 'character': 'His Evil Associate', 'credit_id': "
#  "'52fe45bec3a368484e06c6df', 'gender': 2, 'id': 14488, 'name': 'Snitz "
#  "Edwards', 'order': 1, 'profile_path': None}, {'cast_id': 5, 'character': "
#  "'The Holy Man', 'credit_id': '52fe45bec3a368484e06c6e3', 'gender': 2, 'id': "
#  "108104, 'name': 'Charles Belcher', 'order': 2, 'profile_path': None}, "
#  "{'cast_id': 6, 'character': 'The Princess', 'credit_id': "
#  "'52fe45bec3a368484e06c6e7', 'gender': 1,..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 4, 'character': 'Viktor Navorski', 'credit_id': "
#  "'52fe4259c3a36847f801762f', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', "
#  "'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': "
#  "5, 'character': 'Amelia Warren', 'credit_id': '52fe4259c3a36847f8017633', "
#  "'gender': 1, 'id': 1922, 'name': 'Catherine Zeta-Jones', 'order': 1, "
#  "'profile_path': '/fpWTpvzgINGBSIKFCLNR6iQZ0B8.jpg'}, {'cast_id': 6, "
#  "'character': 'Frank Dixon', 'credit_id': '52fe4259c3a36847f8017637', "
#  "'gender': 2, 'id': 2283, 'name': 'Stanley Tucci', 'order': 2, "
#  "'profile_path': '/omGlTJF2IW5r3L3c5y0qkCt3hFr.jpg'}, {'cast_id': 7, "
#  "'character': 'Mulroy', 'credit_id': '52fe4..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'David Greene', 'credit_id': "
#  "'52fe46109251416c7506bdbd', 'gender': 2, 'id': 18269, 'name': 'Brendan "
#  "Fraser', 'order': 0, 'profile_path': '/n8VOWXp94nhIEo5nS9o6bOpUHiN.jpg'}, "
#  "{'cast_id': 3, 'character': 'Charlie Dillon', 'credit_id': "
#  "'52fe46109251416c7506bdc1', 'gender': 2, 'id': 1892, 'name': 'Matt Damon', "
#  "'order': 1, 'profile_path': '/elSlNgV8xVifsbHpFsqrPGxJToZ.jpg'}, {'cast_id': "
#  "4, 'character': 'Chris Reece', 'credit_id': '52fe46109251416c7506bdc5', "
#  '\'gender\': 2, \'id\': 5577, \'name\': "Chris O\'Donnell", \'order\': 2, '
#  "'profile_path': '/pjIwKa4AkgTzDO2Onz9dPn5KZTr.jpg'}, {'cast_id': 5, "
#  "'character': 'Rip Van Kelt', 'credit_id': '52fe46109251416c7506bdc9', "
#  "'gender': 2, 'id': 36631, 'name': 'Randall Batinkoff', 'order': 3, "
#  "'profile_path': '/aXj1Q2pr70lMPJPRuNB6EIYCujr.jpg'}, {'cast_id': 6, "
#  "'character': 'Chesty Smith', 'credit_id': '52fe46109251416c7506bdcd', "
#  "'gender': 2, 'id': 880, 'name': 'Ben Affleck', 'order': 4, 'profile_path': "
#  "'/cPuPt6mYJ83DjvO3hbjNGug6Fbi.jpg'}, {'cast_id': 7, 'character': 'Sally "
#  "Wheeler', 'credit_id': '52fe46109251416c7506bdd1', 'gender': 1, 'id': 21412, "
#  "'name': 'Amy Locane', 'order': 5, 'profile_path': "
#  "'/6F3aO7rTxHSXTW0Eax3EHSU9Eu2.jpg'}, {'cast_id': 8, 'character': 'Jack "
#  "Connors', 'credit_id': '52fe46109251416c7506bdd5', 'gender': 2, 'id': 6614, "
#  "'name': 'Cole Hauser', 'order': 6, 'profile_path': "
#  "'/2izzcOrZpt22ObHjSNq3qRhrGHu.jpg'}]"), key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'Rock Reilly', 'credit_id': "
#  "'52fe4494c3a368484e02ac77', 'gender': 2, 'id': 13022, 'name': 'Tom "
#  "Berenger', 'order': 0, 'profile_path': '/gueEBgqv1sWFemMXyI4TJ2peuMA.jpg'}, "
#  "{'cast_id': 9, 'character': 'Eddie Devane', 'credit_id': "
#  "'52fe4494c3a368484e02ac9f', 'gender': 2, 'id': 18687, 'name': 'William "
#  "McNamara', 'order': 1, 'profile_path': '/c19069KdW7VW4h8Q5Cq35j8sOMl.jpg'}, "
#  "{'cast_id': 1, 'character': 'Toni Johnson', 'credit_id': "
#  "'52fe4494c3a368484e02ac73', 'gender': 1, 'id': 23764, 'name': '–≠—Ä–∏–∫–∞ "
#  "–≠–ª–µ–Ω–∏–∞–∫', 'order': 2, 'profile_path': "
#  "'/7ZdUGY78qpB2MkTzAQvYEYzncwN.jpg'}, {'cast_id': 10, 'character': 'Howard "
#  "Fins..., key='name')
# _________________________________________________parse_json_cache - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 5, 'character': 'Bobo', 'credit_id': "
#  "'52fe4c7f9251416c910f6c4d', 'gender': 0, 'id': 1171819, 'name': 'Mira "
#  "Barkhammar', 'order': 0, 'profile_path': None}, {'cast_id': 6, 'character': "
#  "'Klara', 'credit_id': '52fe4c7f9251416c910f6c51', 'gender': 0, 'id': "
#  "1171820, 'name': 'Mira Grosin', 'order': 1, 'profile_path': None}, "
#  "{'cast_id': 7, 'character': 'Hedvig', 'credit_id': "
#  "'52fe4c7f9251416c910f6c55', 'gender': 0, 'id': 1171821, 'name': 'Liv "
#  "LeMoyne', 'order': 2, 'profile_path': None}, {'cast_id': 8, 'character': "
#  "'Klaras pappa', 'credit_id': '52fe4c7f9251416c910f6c59', 'gender': 2, 'id': "
#  "93236, 'name': 'David Dencik', 'order': 3, 'profile_path': "
# ..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 10, 'character': 'Samantha Caine / Charly Baltimore', "
#  "'credit_id': '52fe443b9251416c7502d5ad', 'gender': 1, 'id': 16935, 'name': "
#  "'Geena Davis', 'order': 0, 'profile_path': "
#  "'/6b8cRJOItz7yNpYuLCPkl5kv4m2.jpg'}, {'cast_id': 12, 'character': 'Mitch "
#  "Henessey', 'credit_id': '52fe443b9251416c7502d5b1', 'gender': 2, 'id': 2231, "
#  "'name': 'Samuel L. Jackson', 'order': 1, 'profile_path': "
#  "'/AvCReLikjzYEf9XjTQxbv3JWgKT.jpg'}, {'cast_id': 13, 'character': 'Caitlin "
#  "Caine', 'credit_id': '52fe443b9251416c7502d5b5', 'gender': 1, 'id': 37252, "
#  "'name': 'Yvonne Zima', 'order': 2, 'profile_path': "
#  "'/dWA4Hsq8kkFXlmWERCoAh1OqK5M.jpg'}, {'cast_id': 14, 'character': 'Ti..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 8, 'character': 'Reuben Feffer', 'credit_id': "
#  "'52fe4432c3a36847f808804d', 'gender': 2, 'id': 7399, 'name': 'Ben Stiller', "
#  "'order': 0, 'profile_path': '/o9M2PyoF7QDSMq1OwW0D892fIkV.jpg'}, {'cast_id': "
#  "9, 'character': 'Polly Prince', 'credit_id': '52fe4432c3a36847f8088051', "
#  "'gender': 1, 'id': 4491, 'name': 'Jennifer Aniston', 'order': 1, "
#  "'profile_path': '/4d4wvNyDuvN86DoneawbLOpr8gH.jpg'}, {'cast_id': 10, "
#  "'character': 'Sandy Lyle', 'credit_id': '52fe4433c3a36847f8088055', "
#  "'gender': 2, 'id': 1233, 'name': 'Philip Seymour Hoffman', 'order': 2, "
#  "'profile_path': '/vEDJukK8CjIsA0DjNFhoT88TvzS.jpg'}, {'cast_id': 11, "
#  "'character': 'Lisa Kramer', 'credit..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling __main__--content-drive-MyDrive-M2_Project-<ipython-input-7067ccf78c42>.parse_json_cache...
# parse_json_cache(("[{'cast_id': 2, 'character': 'Nathan Harper', 'credit_id': "
#  "'52fe49a5c3a36847f81a5137', 'gender': 2, 'id': 84214, 'name': 'Taylor "
#  "Lautner', 'order': 0, 'profile_path': '/xazf3pX3fbScXvi8WojuxsGOJX2.jpg'}, "
#  "{'cast_id': 3, 'character': 'Karen Murphy', 'credit_id': "
#  "'52fe49a5c3a36847f81a513b', 'gender': 1, 'id': 112561, 'name': 'Lily "
#  "Collins', 'order': 1, 'profile_path': '/zembz1s3BExSTgOGQTbMtXhvfN7.jpg'}, "
#  "{'cast_id': 4, 'character': 'Frank Burton', 'credit_id': "
#  "'52fe49a5c3a36847f81a513f', 'gender': 2, 'id': 658, 'name': 'Alfred Molina', "
#  "'order': 2, 'profile_path': '/uJQVkqEVJGLMaJbwI2tTDlJ9Oo0.jpg'}, {'cast_id': "
#  "5, 'character': 'Kevin Harper', 'credit_id': '..., key='name')
# _________________________________________________parse_json_cache - 0.0s, 0.0min
# CPU times: user 40.7 s, sys: 8.21 s, total: 48.9 s
# Wall time: 6min 55s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 15000, dtype: object

# %%
# %time read_imdb_data.cast.apply(parse_json_cache,key = 'name') # load from the saved cache
# Out:
# CPU times: user 17.1 s, sys: 6.09 s, total: 23.2 s
# Wall time: 1min 58s
# 0       Rob Corddry,Craig Robinson,Clark Duke,Adam Sco...
# 1       Anne Hathaway,Julie Andrews,H√©ctor Elizondo,J...
# 2       Miles Teller,J.K. Simmons,Melissa Benoist,Aust...
# 3       Vidya Balan,Nawazuddin Siddiqui,Parambrata Cha...
# 4       Kim Kang-woo,Jo Jae-hyeon,Park Si-yeon,Kim Joo...
#                               ...
# 2995    Tom Berenger,William McNamara,–≠—Ä–∏–∫–∞ –≠–ª–...
# 2996    Mira Barkhammar,Mira Grosin,Liv LeMoyne,David ...
# 2997    Geena Davis,Samuel L. Jackson,Yvonne Zima,Crai...
# 2998    Ben Stiller,Jennifer Aniston,Philip Seymour Ho...
# 2999    Taylor Lautner,Lily Collins,Alfred Molina,Jaso...
# Name: cast, Length: 15000, dtype: object

# %% [markdown]
# ### Writing data

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/M2_Project'

# %%
# Writing to csv
read_imdb_data.to_csv('read_imdb_data_w.csv', index=False) # Index = False to avoid the index.

# %%
# Writing to excel

# %%
# df
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# df2
data = {'Name': ['John', 'Hop', 'Titan'],
        'Age': [40, 35, 55]}
df2 = pd.DataFrame(data)
df2
# Out:
#     Name  Age
# 0   John   40
# 1    Hop   35
# 2  Titan   55

# %%
with pd.ExcelWriter('dataframe.xlsx') as writer:
    df.to_excel(writer, sheet_name='df')
    df2.to_excel(writer, sheet_name='df2', index = False)

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# Writing to Json

# Convert DataFrame to JSON with 'records' orient
json_str = df.to_json(orient='records')

print(json_str)
# Out:
# [{"Name":"Alice","Age":25},{"Name":"Bob","Age":30},{"Name":"Charlie","Age":35}]

# %%
json_str = df.to_json(orient='columns')

print(json_str)
# Out:
# {"Name":{"0":"Alice","1":"Bob","2":"Charlie"},"Age":{"0":25,"1":30,"2":35}}

# %%
# Convert DataFrame to HTML
html_table = df.to_html(index=False)

# Print or save the HTML table
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Name</th>
#       <th>Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Alice</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <td>Bob</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <td>Charlie</td>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
